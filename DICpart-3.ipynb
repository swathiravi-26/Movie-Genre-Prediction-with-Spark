# %%
import findspark

# %%
findspark.init()

# %%
import pyspark

# %%
from pyspark.sql import *

# %%
from pyspark.ml.clustering import *

# %%
spark = SparkSession \
    .builder \
    .appName("Pyspark Demotrial3") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
df = spark.read.option("inferSchema","true").csv("C:/Users/17169/Documents/train.csv")

# %%
xx = pd.read_csv("C:/Users/17169/Documents/train.csv")

# %%
import pandas as pd

# %%
drama=[]

# %%
xxx = xx['genre']

# %%
xxx_list = xxx_list[:10]

# %%
xxx_list = xxx.tolist()

# %%
comedy=[]
romantic_comedy=[]
romance_film=[]

# %%
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Drama", line):
            print("1")
            drama.append(1)
        else:
            print("2")
            drama.append(0)
# Out:
# ['World cinema', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Science Fiction', 'Drama']
# 1
# ['Musical', 'Action', 'Drama']
# 1
# ['Comedy']
# 2
# ['Crime Fiction', 'World cinema', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 1
# ['Thriller', 'Drama', 'Horror']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Comedy']
# 2
# ['Crime Fiction', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Comedy']
# 2
# ['Comedy']
# 2
# ['Horror']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Horror']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Action', 'Romance Film', 'Indie', 'Thriller']
# 2
# ['Indie', 'Drama']
# 1
# ['Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Adventure', 'Action', 'Drama']
# 1
# ['Drama']
# 1
# ['Romance Film']
# 2
# ['Musical', 'Comedy', 'Romance Film']
# 2
# ['Drama', 'Adventure', 'Action', 'Romance Film']
# 1
# ['Drama']
# 1
# ['Family Film', 'Drama']
# 1
# ['Mystery', 'Horror']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Indie', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'World cinema', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Comedy', 'Romance Film']
# 2
# ['Comedy']
# 2
# ['Comedy']
# 2
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Action/Adventure', 'Adventure', 'World cinema']
# 2
# ['Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Comedy']
# 2
# ['Romantic drama', 'Romance Film']
# 2
# ['Musical', 'Comedy', 'Romance Film', 'Indie', 'Drama']
# 1
# ['Musical']
# 2
# ['Indie', 'Drama']
# 1
# ['Black-and-white']
# 2
# ['Horror']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Horror']
# 2
# ['Action']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Thriller', 'Short Film', 'Horror']
# 2
# ['World cinema']
# 2
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Animation', 'Adventure', 'Family Film']
# 2
# ['Comedy']
# 2
# ['Black-and-white', 'Thriller', 'Mystery', 'Horror']
# 2
# ['Black-and-white', 'Action/Adventure', 'Action']
# 2
# ['Drama']
# 1
# ['Romance Film', 'Mystery', 'Drama']
# 1
# ['Black-and-white', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Black-and-white', 'World cinema', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'World cinema']
# 2
# ['Musical', 'Romance Film', 'Drama']
# 1
# ['Black-and-white', 'Indie', 'World cinema', 'Drama']
# 1
# ['Action', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Crime Fiction', 'Thriller', 'Mystery']
# 2
# ['Action', 'Science Fiction', 'Thriller', 'World cinema']
# 2
# ['Short Film', 'Comedy', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['Musical', 'Comedy', 'Romance Film', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Action/Adventure', 'Crime Fiction', 'Thriller', 'Action']
# 2
# ['Crime Fiction', 'Comedy', 'Thriller', 'Drama']
# 1
# ['Drama']
# 1
# ['Action/Adventure', 'Thriller', 'World cinema']
# 2
# ['World cinema', 'Drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Comedy']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Comedy']
# 2
# ['Thriller']
# 2
# ['Romantic drama', 'Romance Film', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Musical']
# 2
# ['Adventure', 'Action']
# 2
# ['Thriller', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Drama']
# 1
# ['Comedy', 'Short Film']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Adventure']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Action', 'Science Fiction', 'Horror']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Crime Fiction', 'Romantic drama', 'Romance Film', 'Thriller', 'Drama']
# 1
# ['Indie', 'Thriller', 'Mystery', 'Drama', 'World cinema']
# 1
# ['Musical', 'Comedy', 'Horror', 'Short Film']
# 2
# ['Crime Fiction', 'Comedy', 'Action', 'Drama']
# 1
# ['Comedy', 'Family Film']
# 2
# ['World cinema', 'Drama']
# 1
# ['Science Fiction', 'Horror']
# 2
# ['Drama']
# 1
# ['Drama', 'Romance Film', 'Horror']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Action/Adventure', 'Romantic drama']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Thriller', 'Drama', 'Horror']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 2
# ['Crime Fiction', 'Action', 'Drama']
# 1
# ['Musical', 'Family Film']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Science Fiction', 'World cinema']
# 2
# ['Crime Fiction', 'Romantic drama', 'Romance Film', 'Mystery', 'Drama']
# 1
# ['Comedy']
# 2
# ['Animation', 'Science Fiction', 'Short Film', 'World cinema']
# 2
# ['Black-and-white', 'Indie', 'Action', 'Mystery']
# 2
# ['Action/Adventure', 'Drama']
# 1
# ['Crime Fiction', 'Mystery']
# 2
# ['Thriller']
# 2
# ['Drama']
# 1
# ['Thriller', 'Horror']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 1
# ['Black-and-white', 'Indie', 'Short Film', 'Drama']
# 1
# ['Action']
# 2
# ['Comedy', 'Romantic comedy']
# 2
# ['Action', 'Thriller', 'Drama']
# 1
# ['Mystery', 'Indie', 'Comedy', 'Thriller']
# 2
# ['Action/Adventure', 'Indie', 'Action', 'Thriller']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Black-and-white', 'Crime Fiction', 'Thriller']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Black-and-white', 'Adventure', 'Action']
# 2
# ['Drama']
# 1
# ['Animation', 'Musical', 'Short Film']
# 2
# ['Crime Fiction', 'Comedy']
# 2
# ['World cinema', 'Drama']
# 1
# ['Indie', 'Comedy']
# 2
# ['Black-and-white', 'Comedy', 'Family Film']
# 2
# ['Drama', 'Mystery', 'Romance Film']
# 1
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Animation', 'Musical', 'Family Film']
# 2
# ['World cinema', 'Drama']
# 1
# ['Thriller', 'Mystery']
# 2
# ['Horror']
# 2
# ['Action/Adventure', 'Thriller', 'World cinema']
# 2
# ['Indie', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Drama', 'Musical', 'Romance Film']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Crime Fiction', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['Short Film', 'Family Film', 'Action', 'Animation', 'Adventure', 'Science Fiction']
# 2
# ['Horror']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Crime Fiction', 'Thriller', 'Drama', 'Horror']
# 1
# ['Action/Adventure', 'World cinema', 'Drama']
# 1
# ['Drama', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Drama']
# 1
# ['Science Fiction']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Short Film']
# 2
# ['Romance Film']
# 2
# ['Drama']
# 1
# ['Action', 'Drama']
# 1
# ['Family Film', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Indie', 'Adventure', 'Thriller']
# 2
# ['Science Fiction']
# 2
# ['Romance Film']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Action', 'Comedy', 'Romantic comedy', 'Action/Adventure', 'World cinema']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Thriller']
# 2
# ['Indie', 'Comedy']
# 2
# ['Short Film']
# 2
# ['Thriller', 'Horror']
# 2
# ['Science Fiction', 'Comedy', 'Horror']
# 2
# ['Drama']
# 1
# ['Indie', 'World cinema', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Comedy']
# 2
# ['Short Film']
# 2
# ['Black-and-white', 'Musical', 'Drama']
# 1
# ['Family Film', 'Comedy', 'Romance Film', 'Adventure', 'Romantic comedy']
# 2
# ['Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Comedy']
# 2
# ['Drama', 'World cinema', 'Romance Film']
# 1
# ['Science Fiction']
# 2
# ['Musical', 'Comedy', 'World cinema', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Family Film', 'Drama']
# 1
# ['Action/Adventure']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Black-and-white', 'Crime Fiction', 'Drama']
# 1
# ['Family Film', 'Comedy', 'Animation', 'Adventure', 'Science Fiction']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Black-and-white', 'Romance Film', 'Adventure', 'Thriller', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Comedy']
# 2
# ['Musical', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Romance Film', 'Mystery', 'Drama']
# 1
# ['Comedy']
# 2
# ['Crime Fiction']
# 2
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Musical', 'Crime Fiction', 'Romantic drama', 'Romance Film', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Black-and-white']
# 2
# ['Action', 'Romance Film']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Animation', 'Romance Film', 'Drama']
# 1
# ['Romantic comedy', 'Romance Film']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['Animation', 'Comedy']
# 2
# ['Animation', 'Action/Adventure', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 1
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Animation', 'Comedy', 'Short Film']
# 2
# ['Black-and-white', 'Comedy', 'Romance Film']
# 2
# ['Drama', 'Action', 'Romance Film']
# 1
# ['Family Film', 'Drama']
# 1
# ['Romantic comedy']
# 2
# ['Animation', 'Action', 'Short Film']
# 2
# ['Comedy', 'Romantic comedy', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama', 'World cinema']
# 1
# ['Comedy', 'Crime Fiction', 'Action']
# 2
# ['Action', 'Drama']
# 1
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Thriller', 'World cinema']
# 2
# ['Black-and-white', 'Adventure', 'Drama']
# 1
# ['World cinema']
# 2
# ['Science Fiction', 'Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Action', 'Animation', 'Thriller', 'Science Fiction', 'Action/Adventure', 'World cinema']
# 2
# ['Comedy', 'Family Film', 'Romance Film']
# 2
# ['World cinema', 'Drama']
# 1
# ['Indie', 'Comedy', 'Family Film', 'Drama']
# 1
# ['Crime Fiction', 'Action']
# 2
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Action']
# 2
# ['Drama']
# 1
# ['Short Film']
# 2
# ['Comedy']
# 2
# ['Action', 'Comedy']
# 2
# ['Comedy', 'Thriller']
# 2
# ['Black-and-white', 'Romance Film', 'Comedy', 'Drama']
# 1
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Indie', 'World cinema', 'Drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Romantic drama', 'Romance Film', 'Thriller', 'Mystery', 'Drama', 'World cinema']
# 1
# ['Black-and-white', 'Indie', 'Drama']
# 1
# ['Drama', 'Musical', 'Romance Film', 'Romantic drama']
# 1
# ['Black-and-white', 'Drama', 'Romantic drama']
# 1
# ['Thriller', 'Mystery']
# 2
# ['Black-and-white', 'Science Fiction', 'Horror']
# 2
# ['World cinema', 'Drama']
# 1
# ['Comedy']
# 2
# ['Comedy', 'Romance Film']
# 2
# ['Musical', 'World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller']
# 2
# ['Crime Fiction', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Indie', 'Drama']
# 1
# ['Drama']
# 1
# ['Romance Film', 'Action', 'Comedy', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Musical', 'Action', 'Romance Film', 'Adventure', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Comedy']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['Animation', 'Comedy', 'Short Film']
# 2
# ['Comedy', 'Horror']
# 2
# ['Adventure', 'Action', 'Comedy']
# 2
# ['Adventure', 'Comedy', 'Family Film']
# 2
# ['Animation', 'Short Film']
# 2
# ['Musical', 'Action', 'Comedy']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['World cinema', 'Drama']
# 1
# ['Adventure']
# 2
# ['Drama']
# 1
# ['Comedy', 'Crime Fiction', 'Action', 'Romance Film']
# 2
# ['Comedy']
# 2
# ['Comedy', 'Mystery', 'Drama', 'Horror']
# 1
# ['Indie', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Crime Fiction', 'Indie', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Crime Fiction', 'Comedy', 'Romance Film']
# 2
# ['Romance Film']
# 2
# ['Comedy', 'Short Film']
# 2
# ['Comedy']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Science Fiction', 'Comedy']
# 2
# ['Comedy']
# 2
# ['Short Film', 'Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Thriller', 'World cinema']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['Mystery', 'Drama']
# 1
# ['Drama', 'Romance Film']
# 1
# ['Action', 'Drama']
# 1
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Horror']
# 2
# ['Science Fiction', 'Thriller', 'Horror']
# 2
# ['Action', 'Science Fiction', 'Thriller']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Adventure', 'Comedy', 'Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Horror']
# 2
# ['Action/Adventure', 'Adventure', 'Drama']
# 1
# ['Drama']
# 1
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Indie', 'Crime Fiction', 'Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Romantic drama', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Action']
# 2
# ['Drama']
# 1
# ['World cinema', 'Horror']
# 2
# ['World cinema', 'Horror']
# 2
# ['Black-and-white', 'Adventure', 'Action']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Drama']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Comedy']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Animation', 'World cinema', 'Family Film']
# 2
# ['Action', 'Thriller', 'Mystery', 'Drama', 'Action/Adventure']
# 1
# ['Comedy', 'Drama']
# 1
# ['Black-and-white', 'Adventure']
# 2
# ['Science Fiction']
# 2
# ['Musical', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Short Film']
# 2
# ['World cinema', 'Drama']
# 1
# ['Science Fiction']
# 2
# ['Action/Adventure', 'Science Fiction', 'World cinema']
# 2
# ['Science Fiction', 'Drama']
# 1
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Mystery']
# 2
# ['Family Film']
# 2
# ['Musical', 'Comedy', 'Family Film', 'Romance Film']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Comedy']
# 2
# ['Black-and-white', 'Crime Fiction', 'Drama']
# 1
# ['Black-and-white', 'Thriller', 'Drama']
# 1
# ['Animation', 'Adventure', 'Family Film']
# 2
# ['Family Film', 'Comedy', 'Romance Film', 'Science Fiction', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Indie', 'Comedy']
# 2
# ['Indie', 'Drama']
# 1
# ['Crime Fiction', 'Comedy', 'Science Fiction', 'Thriller', 'Drama', 'World cinema']
# 1
# ['Comedy', 'Horror']
# 2
# ['Comedy']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Horror']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Black-and-white']
# 2
# ['Science Fiction']
# 2
# ['Indie', 'Horror']
# 2
# ['Comedy', 'Family Film']
# 2
# ['Romance Film']
# 2
# ['Horror']
# 2
# ['Drama']
# 1
# ['Musical', 'Comedy', 'Horror']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Horror']
# 2
# ['Science Fiction']
# 2
# ['Drama']
# 1
# ['Action', 'Drama']
# 1
# ['Comedy']
# 2
# ['Comedy', 'Horror']
# 2
# ['Indie', 'Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Comedy', 'World cinema']
# 2
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Black-and-white', 'Adventure', 'Drama']
# 1
# ['Animation', 'Adventure', 'Family Film']
# 2
# ['Crime Fiction', 'Science Fiction', 'Thriller', 'Horror']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Black-and-white', 'Action', 'Indie', 'Adventure', 'Drama', 'Action/Adventure']
# 1
# ['Horror']
# 2
# ['Drama']
# 1
# ['Short Film']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['World cinema', 'Drama']
# 1
# ['World cinema', 'Thriller', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Adventure']
# 2
# ['Black-and-white', 'Romantic drama', 'Action', 'Romance Film', 'Drama']
# 1
# ['Action/Adventure']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Action', 'Science Fiction', 'Thriller', 'Horror']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['World cinema', 'Drama']
# 1
# ['Science Fiction', 'Comedy', 'Family Film']
# 2
# ['Thriller', 'Horror']
# 2
# ['Black-and-white', 'Horror', 'Indie', 'Science Fiction', 'Mystery']
# 2
# ['Action']
# 2
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Crime Fiction', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Drama']
# 1
# ['Thriller', 'World cinema']
# 2
# ['Short Film']
# 2
# ['Short Film', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Family Film', 'Comedy', 'Animation', 'Adventure', 'Science Fiction']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 2
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Musical', 'Family Film', 'Comedy', 'Romance Film', 'Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['World cinema', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Action', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Thriller', 'Mystery']
# 2
# ['Black-and-white']
# 2
# ['Indie', 'Drama']
# 1
# ['Drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Thriller', 'Mystery']
# 2
# ['Black-and-white', 'Action', 'Drama']
# 1
# ['Action', 'Comedy', 'Indie', 'Adventure', 'Action/Adventure']
# 2
# ['Animation', 'Adventure', 'Romance Film']
# 2
# ['Action', 'Romance Film', 'Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Thriller', 'Mystery', 'Drama', 'Horror']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Action', 'Animation', 'Adventure', 'Science Fiction', 'Drama', 'World cinema']
# 1
# ['Romance Film']
# 2
# ['Drama']
# 1
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Indie', 'Science Fiction', 'Horror']
# 2
# ['Comedy']
# 2
# ['Adventure', 'World cinema', 'Drama']
# 1
# ['Animation']
# 2
# ['Drama']
# 1
# ['Comedy', 'World cinema', 'Horror']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Horror']
# 2
# ['Crime Fiction', 'Action', 'Drama']
# 1
# ['Black-and-white', 'Thriller', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Short Film']
# 2
# ['Action/Adventure', 'Drama']
# 1
# ['Action', 'Romance Film', 'Drama']
# 1
# ['Comedy']
# 2
# ['Drama', 'Horror']
# 1
# ['Crime Fiction', 'Romantic drama', 'Action', 'Comedy', 'Romance Film', 'Indie', 'Thriller', 'Romantic comedy', 'Drama', 'Action/Adventure']
# 1
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Adventure', 'Family Film', 'Drama']
# 1
# ['Short Film']
# 2
# ['Action/Adventure']
# 2
# ['Black-and-white', 'Adventure', 'Action', 'Short Film']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Crime Fiction', 'Romance Film', 'Drama']
# 1
# ['Animation', 'Science Fiction']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Thriller', 'Drama']
# 1
# ['Crime Fiction']
# 2
# ['World cinema', 'Drama']
# 1
# ['Black-and-white', 'Thriller', 'Mystery', 'Horror']
# 2
# ['World cinema', 'Drama']
# 1
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 1
# ['Black-and-white', 'Musical', 'Drama']
# 1
# ['Adventure', 'Family Film']
# 2
# ['Short Film', 'Horror']
# 2
# ['Black-and-white', 'Indie', 'Drama']
# 1
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Drama', 'Thriller', 'World cinema', 'Romance Film']
# 1
# ['Musical', 'Crime Fiction', 'World cinema', 'Drama']
# 1
# ['Science Fiction', 'Family Film']
# 2
# ['Musical']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Crime Fiction', 'Action', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure']
# 1
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Black-and-white', 'Adventure']
# 2
# ['Action/Adventure', 'Action', 'World cinema']
# 2
# ['Thriller', 'World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Horror']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Comedy']
# 2
# ['Comedy']
# 2
# ['Crime Fiction', 'Thriller', 'World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Action/Adventure', 'Action', 'Comedy', 'World cinema']
# 2
# ['Black-and-white', 'Comedy', 'Indie', 'Short Film']
# 2
# ['Musical', 'Comedy']
# 2
# ['Short Film']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Comedy', 'Drama']
# 1
# ['Black-and-white', 'Indie', 'Short Film']
# 2
# ['Crime Fiction', 'Indie', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Mystery']
# 2
# ['World cinema', 'Drama']
# 1
# ['Black-and-white', 'Crime Fiction', 'Horror', 'Science Fiction', 'Thriller']
# 2
# ['Comedy']
# 2
# ['Musical', 'Indie']
# 2
# ['Black-and-white']
# 2
# ['Comedy', 'Drama']
# 1
# ['Action', 'Comedy', 'Horror']
# 2
# ['Black-and-white', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 1
# ['Action/Adventure', 'Comedy', 'World cinema']
# 2
# ['Short Film']
# 2
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 1
# ['Indie', 'Comedy']
# 2
# ['Black-and-white', 'Action/Adventure', 'Adventure', 'Action']
# 2
# ['Comedy']
# 2
# ['Romance Film']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Drama']
# 1
# ['Indie', 'Horror']
# 2
# ['Short Film']
# 2
# ['Black-and-white']
# 2
# ['Animation', 'Short Film']
# 2
# ['Black-and-white', 'Comedy']
# 2
# ['Crime Fiction', 'Comedy', 'Indie', 'Thriller', 'Drama']
# 1
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Crime Fiction', 'Romantic drama', 'Comedy', 'Romance Film', 'Drama']
# 1
# ['Indie', 'Horror']
# 2
# ['Musical', 'Comedy', 'Drama', 'Horror']
# 1
# ['Crime Fiction', 'Science Fiction', 'Drama']
# 1
# ['Musical', 'World cinema']
# 2
# ['Indie', 'Comedy', 'Short Film']
# 2
# ['Black-and-white', 'Action', 'Thriller']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Action/Adventure', 'Adventure', 'Action', 'Drama']
# 1
# ['Action', 'Indie', 'Adventure', 'Science Fiction', 'Action/Adventure']
# 2
# ['Musical', 'Comedy']
# 2
# ['Animation', 'Short Film']
# 2
# ['Comedy', 'Romance Film']
# 2
# ['Drama', 'Musical', 'Romance Film', 'Romantic drama']
# 1
# ['Indie', 'Comedy']
# 2
# ['Comedy']
# 2
# ['Black-and-white', 'Horror']
# 2
# ['Black-and-white', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Comedy']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Drama']
# 1
# ['Action/Adventure', 'Action', 'Comedy']
# 2
# ['Indie', 'Drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Action', 'Crime Fiction', 'Science Fiction', 'Thriller']
# 2
# ['Black-and-white', 'Adventure']
# 2
# ['Animation', 'Short Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Science Fiction', 'Thriller']
# 2
# ['Action', 'Drama']
# 1
# ['Action/Adventure']
# 2
# ['Crime Fiction']
# 2
# ['Thriller', 'Mystery', 'Drama']
# 1
# ['Action']
# 2
# ['Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Adventure', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Black-and-white', 'Romance Film', 'Drama']
# 1
# ['Drama', 'Action', 'Romance Film', 'Romantic drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Action/Adventure', 'Crime Fiction', 'Action', 'World cinema']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'Adventure', 'Action']
# 2
# ['Comedy', 'Drama']
# 1
# ['Comedy']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'World cinema']
# 2
# ['Romance Film']
# 2
# ['Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Action', 'Thriller', 'Drama']
# 1
# ['Black-and-white', 'Drama']
# 1
# ['Black-and-white', 'Comedy']
# 2
# ['Thriller', 'Drama']
# 1
# ['Indie', 'Drama']
# 1
# ['Romantic comedy']
# 2
# ['Comedy', 'Indie', 'Thriller', 'Drama', 'World cinema']
# 1
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller']
# 2
# ['Comedy', 'World cinema']
# 2
# ['Horror']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Action']
# 2
# ['Family Film', 'Action', 'Comedy', 'Science Fiction', 'Action/Adventure']
# 2
# ['World cinema', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Romance Film', 'Thriller', 'Mystery', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Animation', 'Family Film']
# 2
# ['Adventure', 'Science Fiction', 'Horror']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery']
# 2
# ['Comedy', 'Horror']
# 2
# ['Action', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Crime Fiction', 'Horror', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Mystery', 'Drama']
# 1
# ['Comedy', 'Mystery']
# 2
# ['Crime Fiction', 'Action', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Thriller', 'Horror']
# 2
# ['Animation', 'Comedy', 'Indie', 'Short Film']
# 2
# ['Drama']
# 1
# ['Animation', 'Adventure', 'Family Film']
# 2
# ['Action']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Indie', 'Horror']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Adventure', 'Family Film']
# 2
# ['Short Film']
# 2
# ['Short Film']
# 2
# ['Black-and-white', 'Comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Action']
# 2
# ['Musical', 'World cinema', 'Drama']
# 1
# ['Black-and-white']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Crime Fiction', 'Action', 'Thriller', 'Drama']
# 1
# ['Black-and-white']
# 2
# ['Crime Fiction', 'Horror']
# 2
# ['Science Fiction', 'Comedy', 'Horror']
# 2
# ['Romance Film', 'Comedy', 'Romantic comedy', 'Drama']
# 1
# ['Comedy', 'World cinema']
# 2
# ['Science Fiction']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 1
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Drama']
# 1
# ['Action', 'Thriller']
# 2
# ['Horror']
# 2
# ['Musical', 'Crime Fiction', 'World cinema', 'Drama']
# 1
# ['Black-and-white', 'Mystery', 'Drama']
# 1
# ['Horror']
# 2
# ['Indie', 'Thriller', 'Drama', 'Horror']
# 1
# ['Adventure', 'Action', 'Romance Film', 'Drama']
# 1
# ['Thriller', 'Family Film']
# 2
# ['Action/Adventure', 'Comedy', 'Crime Fiction', 'Action']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Action', 'Thriller']
# 2
# ['Romance Film']
# 2
# ['Thriller', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Adventure', 'Comedy', 'Family Film']
# 2
# ['Romance Film', 'World cinema', 'Drama']
# 1
# ['Indie', 'Romance Film', 'Drama']
# 1
# ['Comedy', 'Romantic comedy']
# 2
# ['Adventure', 'World cinema', 'Drama']
# 1
# ['Short Film', 'Drama']
# 1
# ['Action', 'Comedy']
# 2
# ['Short Film']
# 2
# ['Horror']
# 2
# ['Horror']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'Comedy']
# 2
# ['World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Action/Adventure', 'Science Fiction', 'Thriller']
# 2
# ['Black-and-white', 'Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Short Film']
# 2
# ['Black-and-white', 'Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Short Film']
# 2
# ['Musical', 'World cinema', 'Drama']
# 1
# ['Action', 'Family Film', 'Drama']
# 1
# ['Indie', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Animation', 'Musical', 'Science Fiction', 'Family Film']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Action']
# 2
# ['Mystery', 'Science Fiction', 'Thriller', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Comedy', 'Thriller', 'Action/Adventure', 'World cinema']
# 2
# ['Comedy']
# 2
# ['Animation', 'Comedy', 'Drama']
# 1
# ['Drama']
# 1
# ['Animation', 'Comedy', 'Short Film']
# 2
# ['World cinema', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Drama', 'Short Film']
# 1
# ['Indie', 'Crime Fiction', 'Action', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Drama']
# 1
# ['Action', 'Thriller']
# 2
# ['Horror']
# 2
# ['Drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Romance Film']
# 2
# ['Black-and-white', 'Action/Adventure', 'Action', 'Drama']
# 1
# ['Indie', 'Action', 'Thriller', 'Horror']
# 2
# ['Action/Adventure']
# 2
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Horror']
# 2
# ['Black-and-white']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Crime Fiction', 'Action', 'Indie', 'Thriller', 'Mystery', 'Action/Adventure']
# 2
# ['Family Film']
# 2
# ['Action/Adventure', 'Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Action', 'Thriller']
# 2
# ['Drama']
# 1
# ['Animation', 'Science Fiction', 'Comedy']
# 2
# ['Family Film', 'Action', 'Comedy', 'Adventure', 'Science Fiction', 'Drama']
# 1
# ['Action', 'Comedy', 'Drama']
# 1
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Adventure', 'Action', 'Family Film']
# 2
# ['Musical', 'Comedy', 'Romantic comedy']
# 2
# ['Black-and-white', 'Indie', 'World cinema', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Musical', 'Horror']
# 2
# ['Black-and-white', 'Comedy']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Black-and-white', 'Short Film', 'Family Film', 'Comedy', 'Indie']
# 2
# ['Horror']
# 2
# ['Adventure', 'Comedy', 'Family Film']
# 2
# ['Indie', 'Drama']
# 1
# ['Adventure', 'Family Film', 'Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Thriller']
# 2
# ['Action', 'Drama']
# 1
# ['Drama']
# 1
# ['Indie', 'Drama']
# 1
# ['Science Fiction', 'Adventure', 'Comedy']
# 2
# ['Animation', 'Comedy', 'Family Film']
# 2
# ['Romantic comedy', 'Drama']
# 1
# ['Drama']
# 1
# ['Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Family Film']
# 2
# ['Thriller', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Romance Film', 'Action', 'Thriller', 'Drama']
# 1
# ['Comedy', 'Romance Film']
# 2
# ['Horror']
# 2
# ['Crime Fiction', 'Comedy', 'Indie', 'Thriller', 'Drama']
# 1
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 1
# ['Black-and-white', 'Comedy']
# 2
# ['Science Fiction', 'Comedy', 'Mystery']
# 2
# ['Indie', 'Comedy']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Romance Film']
# 2
# ['Drama', 'World cinema', 'Romance Film']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Adventure', 'Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Comedy', 'World cinema']
# 2
# ['Action', 'Science Fiction', 'Horror']
# 2
# ['Drama']
# 1
# ['Family Film', 'Animation', 'Adventure', 'Science Fiction', 'World cinema']
# 2
# ['Crime Fiction', 'Action', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Romance Film', 'Adventure', 'Thriller']
# 2
# ['Black-and-white', 'Action', 'Romance Film', 'Thriller', 'Mystery', 'Action/Adventure']
# 2
# ['Drama']
# 1
# ['Musical', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 1
# ['Adventure', 'Action', 'Science Fiction', 'Thriller']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Musical', 'Action', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Thriller']
# 2
# ['Musical', 'Drama']
# 1
# ['Romantic drama', 'Drama']
# 1
# ['Animation', 'Musical', 'Short Film']
# 2
# ['Black-and-white', 'Adventure', 'Action', 'Science Fiction']
# 2
# ['Mystery', 'Horror']
# 2
# ['Adventure', 'Science Fiction', 'Family Film', 'Drama']
# 1
# ['Short Film']
# 2
# ['Action', 'Drama']
# 1
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Thriller', 'Horror']
# 2
# ['Comedy', 'Horror']
# 2
# ['Indie']
# 2
# ['Animation', 'Musical', 'Comedy']
# 2
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 1
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 2
# ['Drama', 'Crime Fiction', 'Thriller', 'Romantic drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Adventure', 'Drama']
# 1
# ['Musical', 'Indie', 'Drama']
# 1
# ['Indie', 'Drama']
# 1
# ['Thriller', 'Horror']
# 2
# ['Comedy', 'Drama']
# 1
# ['Comedy', 'Short Film']
# 2
# ['Comedy', 'Family Film']
# 2
# ['Drama', 'Action/Adventure', 'Indie', 'Adventure']
# 1
# ['Comedy', 'Drama']
# 1
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Short Film']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Action', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Animation', 'Thriller', 'Comedy', 'Family Film']
# 2
# ['Drama']
# 1
# ['Musical', 'Romance Film']
# 2
# ['Crime Fiction', 'Horror', 'Action', 'Comedy', 'Adventure', 'Indie', 'Thriller', 'Action/Adventure']
# 2
# ['Comedy']
# 2
# ['Thriller', 'Drama']
# 1
# ['Black-and-white', 'Indie', 'World cinema', 'Drama']
# 1
# ['Adventure']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Romantic drama', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Thriller', 'Mystery', 'Drama']
# 1
# ['Short Film', 'Drama']
# 1
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 1
# ['Black-and-white', 'Comedy']
# 2
# ['Drama']
# 1
# ['Indie', 'Comedy']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Mystery', 'Horror']
# 2
# ['Musical']
# 2
# ['Drama']
# 1
# ['Romantic comedy']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Thriller', 'Mystery', 'Drama']
# 1
# ['Comedy', 'Horror']
# 2
# ['Adventure', 'Comedy']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Horror']
# 2
# ['Indie', 'Comedy']
# 2
# ['Indie', 'Comedy']
# 2
# ['Black-and-white', 'Horror', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Musical', 'Drama']
# 1
# ['Indie', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Drama']
# 1
# ['Comedy', 'Romance Film']
# 2
# ['Action']
# 2
# ['Science Fiction', 'World cinema', 'Horror']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Black-and-white', 'World cinema', 'Drama']
# 1
# ['Indie', 'Crime Fiction', 'Comedy']
# 2
# ['Drama', 'Indie', 'Comedy', 'Romance Film']
# 1
# ['Musical', 'Comedy']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Adventure', 'Action']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Crime Fiction', 'World cinema', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Drama']
# 1
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Comedy', 'World cinema']
# 2
# ['Drama']
# 1
# ['Adventure', 'Drama']
# 1
# ['Short Film']
# 2
# ['Black-and-white', 'Adventure', 'Indie', 'Short Film']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Horror']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Drama']
# 1
# ['Thriller', 'Mystery']
# 2
# ['Comedy']
# 2
# ['Musical', 'Indie', 'Drama']
# 1
# ['Animation', 'Musical', 'Short Film']
# 2
# ['Short Film']
# 2
# ['Black-and-white', 'Crime Fiction', 'Comedy']
# 2
# ['Mystery', 'Comedy', 'Thriller']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Adventure', 'Action', 'Comedy', 'Romance Film']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Animation', 'Adventure', 'Science Fiction']
# 2
# ['Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Short Film', 'Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Thriller', 'Drama', 'Horror']
# 1
# ['Animation', 'Musical', 'Comedy', 'Romantic comedy']
# 2
# ['Black-and-white', 'Action', 'Thriller', 'Mystery']
# 2
# ['Romantic drama']
# 2
# ['Black-and-white', 'Musical', 'Family Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Thriller', 'Family Film']
# 2
# ['Drama']
# 1
# ['Action', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Short Film']
# 2
# ['Romance Film', 'Comedy', 'Romantic comedy', 'Romantic drama']
# 2
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Action', 'Science Fiction', 'World cinema']
# 2
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Black-and-white']
# 2
# ['Mystery', 'Crime Fiction', 'Comedy', 'Thriller']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Action']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Action/Adventure', 'Adventure', 'Action', 'Thriller']
# 2
# ['Science Fiction', 'Thriller']
# 2
# ['Black-and-white', 'Crime Fiction', 'Drama']
# 1
# ['Musical', 'Family Film', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Romantic drama', 'Romance Film', 'Adventure', 'Drama', 'Action/Adventure']
# 1
# ['Drama']
# 1
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 1
# ['Action', 'Thriller']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 1
# ['Romance Film', 'Action', 'Comedy', 'Drama']
# 1
# ['Science Fiction', 'Indie', 'Comedy']
# 2
# ['Comedy', 'Drama']
# 1
# ['Adventure', 'Science Fiction']
# 2
# ['Thriller', 'Horror']
# 2
# ['Family Film', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Crime Fiction', 'Family Film', 'Action', 'Comedy', 'Adventure', 'Drama']
# 1
# ['Romantic comedy']
# 2
# ['Short Film', 'Action', 'Comedy', 'Indie', 'Adventure', 'Science Fiction']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'World cinema', 'Drama']
# 1
# ['Science Fiction', 'Horror']
# 2
# ['Action/Adventure', 'Adventure', 'Action']
# 2
# ['Comedy']
# 2
# ['Comedy', 'Family Film']
# 2
# ['Action', 'Family Film']
# 2
# ['Thriller']
# 2
# ['Drama']
# 1
# ['Musical', 'World cinema', 'Family Film', 'Drama']
# 1
# ['Action', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'World cinema', 'Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery']
# 2
# ['Animation', 'Family Film']
# 2
# ['Black-and-white', 'Family Film', 'Drama']
# 1
# ['Horror']
# 2
# ['Science Fiction', 'Adventure', 'Comedy']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Action']
# 2
# ['Drama', 'Romance Film']
# 1
# ['Drama', 'Science Fiction', 'Romance Film']
# 1
# ['Black-and-white', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Crime Fiction', 'Action', 'Adventure', 'Science Fiction', 'Thriller', 'Drama']
# 1
# ['Animation']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Action/Adventure', 'Horror']
# 2
# ['Drama']
# 1
# ['Thriller']
# 2
# ['Drama']
# 1
# ['Indie', 'Comedy']
# 2
# ['Drama']
# 1
# ['Thriller', 'Drama', 'Horror']
# 1
# ['Adventure', 'Drama']
# 1
# ['Black-and-white', 'Thriller', 'Horror']
# 2
# ['Short Film']
# 2
# ['Action', 'Adventure', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Romantic drama', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Family Film', 'Drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Musical']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Drama']
# 1
# ['Action/Adventure', 'Crime Fiction', 'Comedy', 'Action']
# 2
# ['Thriller']
# 2
# ['Action']
# 2
# ['Romance Film']
# 2
# ['Horror']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Romantic comedy', 'Comedy', 'Family Film']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Horror']
# 2
# ['Adventure']
# 2
# ['Adventure', 'Thriller']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Drama']
# 1
# ['Comedy', 'Family Film']
# 2
# ['Drama']
# 1
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Family Film', 'Action', 'Comedy', 'Adventure', 'Thriller', 'Action/Adventure']
# 2
# ['Adventure', 'Family Film', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Indie', 'Drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Crime Fiction', 'Comedy', 'Indie', 'Thriller', 'Mystery']
# 2
# ['Science Fiction', 'Thriller', 'Horror']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Indie', 'Crime Fiction', 'Action', 'Drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Crime Fiction', 'Mystery', 'Drama']
# 1
# ['Drama']
# 1
# ['Animation', 'Action', 'Science Fiction']
# 2
# ['Action', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Action', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Horror']
# 2
# ['Horror']
# 2
# ['Science Fiction', 'Action/Adventure', 'Adventure', 'Comedy']
# 2
# ['World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Musical', 'Comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Horror']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Action/Adventure', 'Adventure', 'World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Comedy']
# 2
# ['Horror']
# 2
# ['Horror']
# 2
# ['Comedy', 'Crime Fiction', 'Action']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['Comedy', 'Romantic comedy']
# 2
# ['Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 1
# ['Action']
# 2
# ['Action', 'Science Fiction', 'Horror']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Action/Adventure', 'Indie', 'Action', 'Comedy']
# 2
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Drama']
# 1
# ['Romantic drama', 'Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Comedy']
# 2
# ['Black-and-white', 'World cinema', 'Drama']
# 1
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Black-and-white', 'Musical', 'Comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Comedy', 'Horror']
# 2
# ['Animation', 'Comedy', 'Short Film']
# 2
# ['Crime Fiction', 'Thriller']
# 2
# ['Animation', 'Short Film']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Musical', 'World cinema']
# 2
# ['Musical', 'Short Film', 'Family Film', 'Comedy', 'Animation']
# 2
# ['Crime Fiction', 'Mystery', 'Drama']
# 1
# ['Musical', 'Drama']
# 1
# ['Short Film', 'Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Comedy']
# 2
# ['Musical', 'Comedy']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Horror']
# 2
# ['Animation', 'Short Film']
# 2
# ['Musical']
# 2
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Action/Adventure', 'World cinema']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Comedy']
# 2
# ['Action/Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Action', 'Comedy', 'World cinema']
# 2
# ['Crime Fiction', 'Thriller', 'Drama', 'Horror']
# 1
# ['Black-and-white', 'Romantic comedy', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Black-and-white', 'Drama']
# 1
# ['Science Fiction', 'Comedy', 'Drama']
# 1
# ['Crime Fiction']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'Indie', 'Drama']
# 1
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 2
# ['Musical', 'Indie', 'Comedy']
# 2
# ['Mystery', 'Drama']
# 1
# ['Horror']
# 2
# ['Action', 'Indie', 'Science Fiction', 'Thriller', 'Mystery', 'Action/Adventure']
# 2
# ['Comedy']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Science Fiction', 'Horror']
# 2
# ['Thriller', 'Drama']
# 1
# ['Drama']
# 1
# ['Family Film', 'Comedy', 'Adventure', 'Science Fiction', 'Thriller', 'Action/Adventure']
# 2
# ['Comedy']
# 2
# ['Comedy', 'Drama']
# 1
# ['Comedy', 'Horror']
# 2
# ['Comedy']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Romantic drama', 'Action', 'Romance Film', 'Adventure', 'Action/Adventure']
# 2
# ['Short Film']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Drama']
# 1
# ['Horror']
# 2
# ['Black-and-white', 'Thriller', 'Mystery']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'World cinema']
# 2
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Family Film', 'Drama']
# 1
# ['Comedy']
# 2
# ['Musical', 'Comedy', 'Drama', 'Romance Film']
# 1
# ['Action/Adventure', 'Horror']
# 2
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Crime Fiction', 'Romance Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Action', 'World cinema']
# 2
# ['Comedy', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Short Film', 'Drama']
# 1
# ['Thriller', 'Horror']
# 2
# ['Science Fiction', 'Thriller', 'Horror']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Comedy']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 1
# ['Short Film']
# 2
# ['Horror']
# 2
# ['Romantic drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Family Film', 'Action', 'Animation', 'Adventure', 'Science Fiction']
# 2
# ['Action', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Crime Fiction', 'Action', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Crime Fiction', 'Action', 'Drama']
# 1
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Romantic comedy']
# 2
# ['Musical', 'Family Film', 'Drama']
# 1
# ['Action']
# 2
# ['Thriller', 'Horror']
# 2
# ['Family Film', 'Action', 'Comedy', 'Animation', 'Adventure']
# 2
# ['Animation', 'Action', 'Science Fiction']
# 2
# ['Animation', 'Musical']
# 2
# ['Black-and-white', 'Indie', 'Horror']
# 2
# ['Drama']
# 1
# ['Comedy', 'World cinema']
# 2
# ['Thriller', 'Mystery', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama', 'Action', 'Romance Film', 'Romantic drama']
# 1
# ['Indie', 'Drama']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Comedy']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Indie', 'World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama', 'Crime Fiction', 'World cinema', 'Romance Film']
# 1
# ['World cinema', 'Horror']
# 2
# ['World cinema', 'Drama']
# 1
# ['Indie', 'Crime Fiction', 'Family Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Thriller', 'Drama']
# 1
# ['Comedy']
# 2
# ['World cinema', 'Drama']
# 1
# ['Action', 'Comedy', 'Indie', 'Adventure', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Comedy', 'World cinema', 'Romantic comedy', 'Romance Film']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Action', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['Musical']
# 2
# ['Action/Adventure', 'Adventure', 'Action', 'Drama']
# 1
# ['Black-and-white', 'Drama']
# 1
# ['Comedy', 'Family Film']
# 2
# ['Black-and-white', 'Romantic drama', 'Romance Film', 'Indie', 'Drama']
# 1
# ['Science Fiction', 'Mystery', 'Drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Musical']
# 2
# ['Romance Film']
# 2
# ['Black-and-white', 'Musical', 'Comedy', 'Romance Film', 'Romantic comedy']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Drama']
# 1
# ['Drama']
# 1
# ['Action/Adventure', 'World cinema', 'Drama']
# 1
# ['Science Fiction', 'Comedy', 'Short Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Animation', 'Adventure', 'Science Fiction', 'Family Film']
# 2
# ['Thriller', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Comedy', 'Romance Film', 'Thriller', 'Mystery', 'Romantic comedy']
# 2
# ['Action/Adventure', 'Action', 'Comedy']
# 2
# ['Horror']
# 2
# ['Thriller', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Comedy', 'Indie', 'Thriller', 'Action/Adventure']
# 2
# ['Action', 'Adventure', 'Thriller', 'Drama', 'World cinema']
# 1
# ['Action', 'Comedy']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Horror']
# 2
# ['Romance Film']
# 2
# ['Horror']
# 2
# ['Crime Fiction', 'Action', 'Thriller', 'Drama', 'Action/Adventure']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Comedy', 'Drama']
# 1
# ['Adventure', 'Family Film', 'Drama']
# 1
# ['Adventure', 'Science Fiction']
# 2
# ['Comedy', 'Horror']
# 2
# ['Science Fiction', 'Horror']
# 2
# ['Adventure', 'Action']
# 2
# ['Comedy']
# 2
# ['Horror']
# 2
# ['Crime Fiction', 'Comedy', 'Indie', 'Thriller', 'Drama']
# 1
# ['Black-and-white', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Drama']
# 1
# ['Black-and-white', 'Comedy', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 1
# ['World cinema', 'Drama', 'Horror']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Black-and-white', 'Short Film']
# 2
# ['Drama']
# 1
# ['Thriller', 'Mystery', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'World cinema']
# 2
# ['World cinema', 'Drama']
# 1
# ['Indie']
# 2
# ['Comedy', 'Romance Film']
# 2
# ['Indie', 'Comedy', 'Family Film']
# 2
# ['Thriller', 'Drama']
# 1
# ['Thriller', 'Horror']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Thriller']
# 2
# ['Indie', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Drama', 'Musical', 'Romance Film']
# 1
# ['Musical', 'Romance Film']
# 2
# ['Animation', 'Short Film']
# 2
# ['Family Film', 'Drama']
# 1
# ['Action/Adventure', 'Crime Fiction', 'Action', 'Drama']
# 1
# ['Short Film']
# 2
# ['Action', 'Animation', 'Science Fiction', 'Thriller', 'Action/Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Comedy']
# 2
# ['Action']
# 2
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Action/Adventure', 'World cinema']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Comedy']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Action/Adventure', 'Action', 'Science Fiction', 'Thriller']
# 2
# ['Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Crime Fiction', 'Action', 'Thriller', 'Drama', 'Action/Adventure']
# 1
# ['Black-and-white', 'Short Film', 'Family Film', 'Comedy', 'Indie']
# 2
# ['Drama']
# 1
# ['Drama', 'Musical', 'Romance Film', 'Romantic drama']
# 1
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 2
# ['Action/Adventure', 'Action', 'World cinema']
# 2
# ['Musical', 'Comedy', 'Drama']
# 1
# ['Horror']
# 2
# ['Drama', 'Comedy', 'Romance Film', 'Horror']
# 1
# ['World cinema']
# 2
# ['Action', 'Romance Film']
# 2
# ['Comedy']
# 2
# ['Action/Adventure', 'World cinema', 'Drama']
# 1
# ['Family Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Musical', 'Comedy', 'Family Film']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Science Fiction']
# 2
# ['Action', 'Comedy']
# 2
# ['Indie', 'Drama']
# 1
# ['Indie', 'Crime Fiction']
# 2
# ['Indie', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Musical', 'Short Film']
# 2
# ['Crime Fiction', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Science Fiction', 'Thriller', 'Drama', 'Horror']
# 1
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Musical', 'World cinema', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Animation', 'Action', 'Drama']
# 1
# ['Horror']
# 2
# ['Drama']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Drama']
# 1
# ['Animation', 'Adventure', 'Action', 'Science Fiction']
# 2
# ['Black-and-white', 'Romance Film']
# 2
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Comedy', 'Family Film']
# 2
# ['Action', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure']
# 1
# ['Indie']
# 2
# ['Mystery', 'Adventure', 'Comedy', 'Family Film']
# 2
# ...
# 2
# ['Crime Fiction', 'Thriller', 'Horror']
# 2
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Black-and-white']
# 2
# ['Drama']
# 1
# ['Adventure', 'Drama']
# 1
# ['Thriller']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Indie', 'Thriller', 'Drama']
# 1
# ['Action', 'Science Fiction', 'Horror']
# 2
# ['Romance Film']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Indie', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Adventure', 'Action', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Crime Fiction', 'Action', 'Comedy', 'Thriller', 'Action/Adventure']
# 2
# ['Musical']
# 2
# ['Black-and-white']
# 2
# ['Action/Adventure', 'Adventure', 'World cinema', 'Family Film']
# 2
# ['Short Film']
# 2
# ['Science Fiction', 'Horror']
# 2
# ['Horror']
# 2
# ['Animation', 'Short Film']
# 2
# ['Romance Film', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Crime Fiction', 'Action', 'Comedy', 'Thriller', 'Mystery']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Black-and-white', 'Indie', 'Short Film']
# 2
# ['Adventure']
# 2
# ['Animation', 'Comedy', 'Family Film']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Thriller']
# 2
# ['Comedy', 'Family Film']
# 2
# ['Black-and-white', 'Comedy']
# 2
# ['Horror']
# 2
# ['Action', 'Science Fiction']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Black-and-white', 'Thriller']
# 2
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['World cinema', 'Thriller', 'Mystery']
# 2
# ['Romance Film', 'Thriller', 'Drama']
# 1
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Adventure', 'Science Fiction']
# 2
# ['Horror']
# 2
# ['Action']
# 2
# ['Comedy', 'Thriller', 'Drama', 'Horror']
# 1
# ['Animation']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Action/Adventure', 'Musical', 'World cinema', 'Drama']
# 1
# ['Adventure', 'Family Film', 'Drama']
# 1
# ['Horror', 'Action', 'Comedy', 'Science Fiction', 'Action/Adventure', 'World cinema']
# 2
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Crime Fiction', 'World cinema', 'Drama']
# 1
# ['Drama', 'Romance Film']
# 1
# ['Indie', 'Drama']
# 1
# ['Action', 'Comedy', 'Romance Film', 'Romantic comedy', 'Action/Adventure']
# 2
# ['Black-and-white', 'Comedy']
# 2
# ['Black-and-white']
# 2
# ['Romance Film']
# 2
# ['Musical', 'Action', 'Romance Film']
# 2
# ['Animation', 'Adventure', 'Science Fiction', 'Family Film']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['Thriller', 'Horror']
# 2
# ['Short Film']
# 2
# ['Adventure']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Comedy']
# 2
# ['Crime Fiction', 'Action', 'Thriller', 'Drama', 'Action/Adventure']
# 1
# ['Drama', 'Romance Film', 'Mystery', 'Romantic drama']
# 1
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Thriller', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Crime Fiction', 'Comedy', 'Thriller', 'Drama', 'World cinema']
# 1
# ['Crime Fiction', 'Action', 'Drama']
# 1
# ['Musical', 'Drama']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Science Fiction', 'Thriller', 'Horror']
# 2
# ['Musical', 'Comedy']
# 2
# ['Comedy', 'Horror']
# 2
# ['Crime Fiction']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Comedy', 'Short Film']
# 2
# ['Action']
# 2
# ['Action']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Animation', 'Family Film']
# 2
# ['Indie', 'Comedy']
# 2
# ['Drama']
# 1
# ['Thriller']
# 2
# ['Crime Fiction', 'World cinema', 'Drama']
# 1
# ['Romantic drama', 'Romance Film', 'Thriller', 'Drama', 'World cinema']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Short Film']
# 2
# ['Crime Fiction', 'Action', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Black-and-white', 'Comedy', 'Indie', 'Short Film']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'Thriller', 'Drama', 'Horror']
# 1
# ['Comedy']
# 2
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Romance Film', 'Comedy', 'Romantic comedy', 'Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Thriller', 'World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Thriller', 'Horror']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Drama']
# 1
# ['Drama']
# 1
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Action']
# 2
# ['Crime Fiction', 'Comedy']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Drama']
# 1
# ['Adventure']
# 2
# ['Action/Adventure', 'Musical', 'Thriller', 'World cinema']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Drama', 'Romance Film', 'Thriller', 'Romantic drama']
# 1
# ['Action', 'Comedy', 'Romance Film', 'Animation', 'Adventure', 'Science Fiction']
# 2
# ['Musical', 'Family Film']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Indie', 'Science Fiction']
# 2
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Action', 'Drama']
# 1
# ['Comedy']
# 2
# ['Black-and-white', 'Indie']
# 2
# ['Indie', 'Short Film']
# 2
# ['Indie', 'Comedy']
# 2
# ['World cinema', 'Drama']
# 1
# ['Thriller']
# 2
# ['Comedy', 'World cinema', 'Horror']
# 2
# ['World cinema', 'Drama']
# 1
# ['Comedy']
# 2
# ['Musical', 'Drama']
# 1
# ['Drama']
# 1
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 1
# ['Science Fiction', 'Horror']
# 2
# ['Musical', 'Comedy', 'Family Film']
# 2
# ['Action/Adventure']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Crime Fiction', 'Thriller']
# 2
# ['Musical', 'Indie', 'Comedy']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Romantic drama', 'Romance Film', 'Indie', 'Drama', 'World cinema']
# 1
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Horror', 'Action', 'Thriller', 'Action/Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Adventure', 'Action', 'Comedy']
# 2
# ['Action/Adventure', 'Action', 'Comedy', 'Thriller']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Horror']
# 2
# ['Black-and-white', 'Comedy']
# 2
# ['Action/Adventure', 'Drama']
# 1
# ['Adventure', 'Short Film']
# 2
# ['Drama']
# 1
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Action', 'Comedy', 'Romance Film']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Action/Adventure', 'Adventure', 'Horror']
# 2
# ['Short Film']
# 2
# ['Short Film']
# 2
# ['Musical', 'Comedy', 'Drama']
# 1
# ['Musical']
# 2
# ['Science Fiction', 'Comedy']
# 2
# ['Comedy']
# 2
# ['Short Film']
# 2
# ['World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Indie', 'Crime Fiction', 'Comedy', 'Drama']
# 1
# ['Indie', 'Thriller', 'Drama']
# 1
# ['Action/Adventure', 'Adventure', 'Drama']
# 1
# ['Crime Fiction', 'Comedy', 'Thriller', 'Drama']
# 1
# ['Family Film', 'Drama']
# 1
# ['Horror']
# 2
# ['Comedy', 'Romance Film']
# 2
# ['Horror']
# 2
# ['Drama']
# 1
# ['Crime Fiction', 'Short Film', 'Horror', 'Thriller', 'Mystery']
# 2
# ['Animation', 'Short Film']
# 2
# ['Crime Fiction', 'Drama']
# 1
# ['Mystery', 'Drama']
# 1
# ['Thriller', 'Drama', 'Horror']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Action']
# 2
# ['Drama']
# 1
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Indie', 'Drama']
# 1
# ['Animation']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Romance Film']
# 2
# ['Romance Film']
# 2
# ['Action', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Indie', 'Thriller', 'Drama']
# 1
# ['Drama']
# 1
# ['Musical', 'Romantic drama', 'Horror', 'Romance Film', 'Drama']
# 1
# ['Horror']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Musical', 'World cinema', 'Drama']
# 1
# ['Horror']
# 2
# ['Comedy', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Indie', 'Short Film']
# 2
# ['Comedy']
# 2
# ['Musical', 'World cinema', 'Drama']
# 1
# ['Adventure', 'Crime Fiction', 'Drama']
# 1
# ['Comedy', 'Romantic drama']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 2
# ['Comedy']
# 2
# ['Action', 'Comedy', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Science Fiction', 'Thriller']
# 2
# ['Thriller', 'Mystery']
# 2
# ['Thriller', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Black-and-white', 'World cinema', 'Drama']
# 1
# ['Science Fiction']
# 2
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Crime Fiction', 'Action', 'Comedy', 'Adventure', 'Thriller', 'Action/Adventure']
# 2
# ['Drama']
# 1
# ['Short Film']
# 2
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Mystery', 'Horror']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Adventure', 'Science Fiction', 'Drama']
# 1
# ['Animation', 'Family Film']
# 2
# ['Action/Adventure', 'Mystery']
# 2
# ['World cinema', 'Comedy', 'Thriller', 'Drama']
# 1
# ['Thriller', 'World cinema', 'Horror']
# 2
# ['Musical', 'World cinema']
# 2
# ['Comedy', 'Horror']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 1
# ['Comedy']
# 2
# ['Crime Fiction', 'World cinema', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Drama', 'Musical', 'Romance Film']
# 1
# ['Animation', 'Musical', 'Family Film', 'Drama']
# 1
# ['Crime Fiction', 'Drama']
# 1
# ['Family Film', 'Drama']
# 1
# ['Romantic comedy']
# 2
# ['Black-and-white', 'Drama']
# 1
# ['Musical', 'Thriller', 'World cinema']
# 2
# ['Science Fiction', 'Adventure', 'Action', 'Comedy']
# 2
# ['Drama']
# 1
# ['Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Action', 'Romance Film', 'Drama']
# 1
# ['Indie', 'Mystery', 'Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Drama']
# 1
# ['Musical', 'Romance Film']
# 2
# ['Drama', 'Romance Film']
# 1
# ['Romance Film']
# 2
# ['Animation', 'Comedy', 'Short Film']
# 2
# ['Horror']
# 2
# ['Drama']
# 1
# ['Horror']
# 2
# ['World cinema', 'Drama']
# 1
# ['Comedy', 'Indie', 'Crime Fiction', 'Action']
# 2
# ['Drama']
# 1
# ['Action']
# 2
# ['Mystery']
# 2
# ['Romantic drama', 'Romance Film', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Drama']
# 1
# ['Short Film']
# 2
# ['Animation', 'Adventure', 'Action', 'Family Film']
# 2
# ['Musical', 'Crime Fiction', 'Romantic drama', 'Action', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Drama']
# 1
# ['Musical', 'Comedy', 'World cinema']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Drama', 'Adventure', 'Action', 'Romance Film']
# 1
# ['Musical', 'World cinema']
# 2
# ['Drama']
# 1
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Indie', 'Short Film']
# 2
# ['Romance Film', 'World cinema', 'Drama']
# 1
# ['Action']
# 2
# ['Science Fiction', 'Musical', 'Comedy']
# 2
# ['Animation', 'Comedy', 'Family Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Black-and-white', 'Comedy', 'Drama']
# 1
# ['Thriller', 'World cinema', 'Drama']
# 1
# ['Horror']
# 2
# ['Comedy']
# 2
# ['Musical']
# 2
# ['World cinema', 'Drama']
# 1
# ['Science Fiction', 'Comedy', 'Family Film']
# 2
# ['Action/Adventure']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 1
# ['Musical', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Drama']
# 1
# ['Thriller', 'World cinema', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Horror']
# 2
# ['Action', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'Action/Adventure']
# 1
# ['Animation']
# 2
# ['Black-and-white', 'Comedy', 'Short Film', 'Family Film']
# 2
# ['Drama', 'Romance Film']
# 1
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Drama']
# 1
# ['Black-and-white']
# 2
# ['Adventure', 'Comedy', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['World cinema', 'Drama', 'Horror']
# 1
# ['Horror']
# 2
# ['Drama']
# 1
# ['Black-and-white', 'Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Action/Adventure']
# 2
# ['Indie', 'Drama']
# 1
# ['Adventure']
# 2
# ['Comedy', 'Horror']
# 2
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Indie', 'World cinema', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Drama', 'Science Fiction', 'Thriller', 'Romance Film']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Black-and-white', 'Adventure']
# 2
# ['Action/Adventure', 'Comedy', 'World cinema']
# 2
# ['Drama']
# 1
# ['Indie', 'Crime Fiction', 'Thriller', 'Drama']
# 1
# ['Black-and-white', 'Drama']
# 1
# ['Drama']
# 1
# ['Adventure', 'Action']
# 2
# ['Crime Fiction', 'Horror', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Black-and-white', 'Indie', 'Action', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Indie', 'Comedy']
# 2
# ['Action', 'Comedy', 'Adventure', 'Drama', 'World cinema']
# 1
# ['Action', 'Thriller', 'Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Science Fiction']
# 2
# ['Indie', 'Comedy']
# 2
# ['Romance Film']
# 2
# ['Musical', 'Crime Fiction', 'Action', 'Comedy', 'Drama', 'World cinema']
# 1
# ['Comedy', 'Drama']
# 1
# ['World cinema', 'Drama']
# 1
# ['Horror']
# 2
# ['Comedy', 'Short Film']
# 2
# ['Drama', 'Family Film', 'Romance Film']
# 1
# ['Indie', 'Comedy']
# 2
# ['Black-and-white', 'Comedy', 'Horror', 'Short Film']
# 2
# ['Science Fiction', 'Horror']
# 2
# ['Indie', 'Short Film', 'Drama']
# 1
# ['Science Fiction', 'World cinema']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Action', 'World cinema']
# 2
# ['Drama']
# 1
# ['Indie', 'Drama']
# 1
# ['Adventure']
# 2
# ['Romance Film']
# 2
# ['Musical', 'Comedy']
# 2
# ['Horror']
# 2
# ['Musical', 'Comedy', 'World cinema', 'Romance Film']
# 2
# ['Comedy']
# 2
# ['Animation', 'World cinema', 'Science Fiction', 'Thriller']
# 2
# ['Action/Adventure', 'Action']
# 2
# ['Action', 'Science Fiction']
# 2
# ['Drama']
# 1
# ['Action']
# 2
# ['Adventure', 'Action']
# 2
# ['Black-and-white', 'Action/Adventure', 'Action']
# 2
# ['Crime Fiction', 'Thriller', 'Action']
# 2
# ['Comedy', 'Drama']
# 1
# ['Short Film']
# 2
# ['Comedy']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 2
# ['Crime Fiction', 'Comedy', 'Action', 'Romance Film']
# 2
# ['Indie', 'Short Film']
# 2
# ['Comedy', 'Horror']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Horror']
# 2
# ['Indie', 'Drama']
# 1
# ['Action/Adventure', 'Adventure']
# 2
# ['Indie', 'Comedy']
# 2
# ['Comedy']
# 2
# ['Action', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Thriller', 'Mystery', 'Action/Adventure']
# 2
# ['Drama']
# 1
# ['Thriller']
# 2
# ['Short Film', 'Horror']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Action', 'Drama']
# 1
# ['Drama', 'Romance Film']
# 1
# ['Crime Fiction', 'Romantic drama', 'Romance Film', 'Thriller', 'Mystery', 'Drama', 'World cinema']
# 1
# ['Action/Adventure', 'Adventure', 'Action', 'Comedy']
# 2
# ['Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Science Fiction', 'Horror']
# 2
# ['Action/Adventure', 'Adventure', 'Science Fiction', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 2
# ['Horror']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Crime Fiction', 'Drama']
# 1
# ['Comedy']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 1
# ['Black-and-white', 'Drama', 'Romance Film']
# 1
# ['Crime Fiction', 'Action', 'Mystery', 'Romance Film']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Black-and-white', 'Short Film', 'Drama']
# 1
# ['Black-and-white', 'Drama']
# 1
# ['Drama']
# 1
# ['Thriller', 'Drama']
# 1
# ['Science Fiction', 'Comedy', 'Family Film']
# 2
# ['Drama']
# 1
# ['Mystery', 'Science Fiction', 'Thriller']
# 2
# ['Adventure', 'Crime Fiction', 'Action', 'Mystery']
# 2
# ['Adventure', 'Science Fiction', 'Thriller']
# 2
# ['Romance Film', 'World cinema', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Black-and-white', 'Musical', 'Drama']
# 1
# ['Thriller', 'World cinema', 'Drama']
# 1
# ['Drama']
# 1
# ['Animation', 'Science Fiction']
# 2
# ['Romantic comedy', 'Comedy', 'Family Film', 'Romance Film']
# 2
# ['Drama']
# 1
# ['Short Film']
# 2
# ['Comedy', 'World cinema']
# 2
# ['Indie']
# 2
# ['Drama']
# 1
# ['Romance Film', 'Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Action', 'Comedy', 'Thriller', 'Action/Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Action', 'Thriller']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2
# ['Action', 'Adventure', 'Science Fiction', 'Thriller', 'Drama', 'Action/Adventure']
# 1
# ['Musical', 'Family Film', 'Drama']
# 1
# ['Short Film']
# 2
# ['Drama']
# 1
# ['Thriller', 'Drama']
# 1
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama']
# 1
# ['Action', 'Drama']
# 1
# ['Indie', 'World cinema', 'Drama']
# 1
# ['Action', 'Drama']
# 1
# ['Comedy', 'Indie', 'Short Film']
# 2
# ['Adventure', 'Science Fiction']
# 2
# ['Action/Adventure', 'World cinema', 'Science Fiction', 'Thriller']
# 2
# ['Horror']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 1
# ['Comedy']
# 2
# ['Drama']
# 1
# ['Comedy']
# 2

# %%
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Comedy", line):
            print("1")
            comedy.append(1)
        else:
            print("2")
            comedy.append(0)
# Out:
# ['World cinema', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Science Fiction', 'Drama']
# 2
# ['Musical', 'Action', 'Drama']
# 2
# ['Comedy']
# 1
# ['Crime Fiction', 'World cinema', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 2
# ['Thriller', 'Drama', 'Horror']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Comedy']
# 1
# ['Crime Fiction', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Comedy']
# 1
# ['Comedy']
# 1
# ['Horror']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Horror']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Action', 'Romance Film', 'Indie', 'Thriller']
# 2
# ['Indie', 'Drama']
# 2
# ['Drama']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Adventure', 'Action', 'Drama']
# 2
# ['Drama']
# 2
# ['Romance Film']
# 2
# ['Musical', 'Comedy', 'Romance Film']
# 1
# ['Drama', 'Adventure', 'Action', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Family Film', 'Drama']
# 2
# ['Mystery', 'Horror']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Indie', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'World cinema', 'Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Comedy', 'Romance Film']
# 1
# ['Comedy']
# 1
# ['Comedy']
# 1
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Action/Adventure', 'Adventure', 'World cinema']
# 2
# ['Drama']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Comedy']
# 1
# ['Romantic drama', 'Romance Film']
# 2
# ['Musical', 'Comedy', 'Romance Film', 'Indie', 'Drama']
# 1
# ['Musical']
# 2
# ['Indie', 'Drama']
# 2
# ['Black-and-white']
# 2
# ['Horror']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Action/Adventure', 'Action', 'Thriller', 'Horror']
# 2
# ['Action']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Thriller', 'Short Film', 'Horror']
# 2
# ['World cinema']
# 2
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Animation', 'Adventure', 'Family Film']
# 2
# ['Comedy']
# 1
# ['Black-and-white', 'Thriller', 'Mystery', 'Horror']
# 2
# ['Black-and-white', 'Action/Adventure', 'Action']
# 2
# ['Drama']
# 2
# ['Romance Film', 'Mystery', 'Drama']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Black-and-white', 'World cinema', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'World cinema']
# 2
# ['Musical', 'Romance Film', 'Drama']
# 2
# ['Black-and-white', 'Indie', 'World cinema', 'Drama']
# 2
# ['Action', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery']
# 2
# ['Action', 'Science Fiction', 'Thriller', 'World cinema']
# 2
# ['Short Film', 'Comedy', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['Musical', 'Comedy', 'Romance Film', 'Thriller', 'Mystery', 'Drama']
# 1
# ['Comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Thriller', 'Action']
# 2
# ['Crime Fiction', 'Comedy', 'Thriller', 'Drama']
# 1
# ['Drama']
# 2
# ['Action/Adventure', 'Thriller', 'World cinema']
# 2
# ['World cinema', 'Drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Comedy']
# 1
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Comedy']
# 1
# ['Thriller']
# 2
# ['Romantic drama', 'Romance Film', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Musical']
# 2
# ['Adventure', 'Action']
# 2
# ['Thriller', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Drama']
# 1
# ['Comedy', 'Short Film']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Adventure']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Action', 'Science Fiction', 'Horror']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Black-and-white', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Crime Fiction', 'Romantic drama', 'Romance Film', 'Thriller', 'Drama']
# 2
# ['Indie', 'Thriller', 'Mystery', 'Drama', 'World cinema']
# 2
# ['Musical', 'Comedy', 'Horror', 'Short Film']
# 1
# ['Crime Fiction', 'Comedy', 'Action', 'Drama']
# 1
# ['Comedy', 'Family Film']
# 1
# ['World cinema', 'Drama']
# 2
# ['Science Fiction', 'Horror']
# 2
# ['Drama']
# 2
# ['Drama', 'Romance Film', 'Horror']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Action/Adventure', 'Romantic drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Thriller', 'Drama', 'Horror']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 1
# ['Crime Fiction', 'Action', 'Drama']
# 2
# ['Musical', 'Family Film']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Science Fiction', 'World cinema']
# 2
# ['Crime Fiction', 'Romantic drama', 'Romance Film', 'Mystery', 'Drama']
# 2
# ['Comedy']
# 1
# ['Animation', 'Science Fiction', 'Short Film', 'World cinema']
# 2
# ['Black-and-white', 'Indie', 'Action', 'Mystery']
# 2
# ['Action/Adventure', 'Drama']
# 2
# ['Crime Fiction', 'Mystery']
# 2
# ['Thriller']
# 2
# ['Drama']
# 2
# ['Thriller', 'Horror']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 2
# ['Black-and-white', 'Indie', 'Short Film', 'Drama']
# 2
# ['Action']
# 2
# ['Comedy', 'Romantic comedy']
# 1
# ['Action', 'Thriller', 'Drama']
# 2
# ['Mystery', 'Indie', 'Comedy', 'Thriller']
# 1
# ['Action/Adventure', 'Indie', 'Action', 'Thriller']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Black-and-white', 'Crime Fiction', 'Thriller']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Black-and-white', 'Adventure', 'Action']
# 2
# ['Drama']
# 2
# ['Animation', 'Musical', 'Short Film']
# 2
# ['Crime Fiction', 'Comedy']
# 1
# ['World cinema', 'Drama']
# 2
# ['Indie', 'Comedy']
# 1
# ['Black-and-white', 'Comedy', 'Family Film']
# 1
# ['Drama', 'Mystery', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Animation', 'Musical', 'Family Film']
# 2
# ['World cinema', 'Drama']
# 2
# ['Thriller', 'Mystery']
# 2
# ['Horror']
# 2
# ['Action/Adventure', 'Thriller', 'World cinema']
# 2
# ['Indie', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama', 'Musical', 'Romance Film']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Crime Fiction', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['Short Film', 'Family Film', 'Action', 'Animation', 'Adventure', 'Science Fiction']
# 2
# ['Horror']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Thriller', 'Drama', 'Horror']
# 2
# ['Action/Adventure', 'World cinema', 'Drama']
# 2
# ['Drama', 'Romantic comedy', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Science Fiction']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Short Film']
# 2
# ['Romance Film']
# 2
# ['Drama']
# 2
# ['Action', 'Drama']
# 2
# ['Family Film', 'Drama']
# 2
# ['Crime Fiction', 'Action', 'Indie', 'Adventure', 'Thriller']
# 2
# ['Science Fiction']
# 2
# ['Romance Film']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Action', 'Comedy', 'Romantic comedy', 'Action/Adventure', 'World cinema']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Thriller']
# 2
# ['Indie', 'Comedy']
# 1
# ['Short Film']
# 2
# ['Thriller', 'Horror']
# 2
# ['Science Fiction', 'Comedy', 'Horror']
# 1
# ['Drama']
# 2
# ['Indie', 'World cinema', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Drama']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Comedy']
# 1
# ['Short Film']
# 2
# ['Black-and-white', 'Musical', 'Drama']
# 2
# ['Family Film', 'Comedy', 'Romance Film', 'Adventure', 'Romantic comedy']
# 1
# ['Romance Film', 'Romantic comedy', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Comedy']
# 1
# ['Drama', 'World cinema', 'Romance Film']
# 2
# ['Science Fiction']
# 2
# ['Musical', 'Comedy', 'World cinema', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Family Film', 'Drama']
# 2
# ['Action/Adventure']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Black-and-white', 'Crime Fiction', 'Drama']
# 2
# ['Family Film', 'Comedy', 'Animation', 'Adventure', 'Science Fiction']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Black-and-white', 'Romance Film', 'Adventure', 'Thriller', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Comedy']
# 1
# ['Musical', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Crime Fiction', 'Action', 'Romance Film', 'Mystery', 'Drama']
# 2
# ['Comedy']
# 1
# ['Crime Fiction']
# 2
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Musical', 'Crime Fiction', 'Romantic drama', 'Romance Film', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Black-and-white']
# 2
# ['Action', 'Romance Film']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Animation', 'Romance Film', 'Drama']
# 2
# ['Romantic comedy', 'Romance Film']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Animation', 'Comedy']
# 1
# ['Animation', 'Action/Adventure', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Animation', 'Comedy', 'Short Film']
# 1
# ['Black-and-white', 'Comedy', 'Romance Film']
# 1
# ['Drama', 'Action', 'Romance Film']
# 2
# ['Family Film', 'Drama']
# 2
# ['Romantic comedy']
# 2
# ['Animation', 'Action', 'Short Film']
# 2
# ['Comedy', 'Romantic comedy', 'Drama']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama', 'World cinema']
# 2
# ['Comedy', 'Crime Fiction', 'Action']
# 1
# ['Action', 'Drama']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Thriller', 'World cinema']
# 2
# ['Black-and-white', 'Adventure', 'Drama']
# 2
# ['World cinema']
# 2
# ['Science Fiction', 'Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Action', 'Animation', 'Thriller', 'Science Fiction', 'Action/Adventure', 'World cinema']
# 2
# ['Comedy', 'Family Film', 'Romance Film']
# 1
# ['World cinema', 'Drama']
# 2
# ['Indie', 'Comedy', 'Family Film', 'Drama']
# 1
# ['Crime Fiction', 'Action']
# 2
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Action']
# 2
# ['Drama']
# 2
# ['Short Film']
# 2
# ['Comedy']
# 1
# ['Action', 'Comedy']
# 1
# ['Comedy', 'Thriller']
# 1
# ['Black-and-white', 'Romance Film', 'Comedy', 'Drama']
# 1
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Indie', 'World cinema', 'Drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Romantic drama', 'Romance Film', 'Thriller', 'Mystery', 'Drama', 'World cinema']
# 2
# ['Black-and-white', 'Indie', 'Drama']
# 2
# ['Drama', 'Musical', 'Romance Film', 'Romantic drama']
# 2
# ['Black-and-white', 'Drama', 'Romantic drama']
# 2
# ['Thriller', 'Mystery']
# 2
# ['Black-and-white', 'Science Fiction', 'Horror']
# 2
# ['World cinema', 'Drama']
# 2
# ['Comedy']
# 1
# ['Comedy', 'Romance Film']
# 1
# ['Musical', 'World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller']
# 2
# ['Crime Fiction', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Indie', 'Drama']
# 2
# ['Drama']
# 2
# ['Romance Film', 'Action', 'Comedy', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Musical', 'Action', 'Romance Film', 'Adventure', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Comedy']
# 1
# ['Black-and-white', 'Drama']
# 2
# ['Animation', 'Comedy', 'Short Film']
# 1
# ['Comedy', 'Horror']
# 1
# ['Adventure', 'Action', 'Comedy']
# 1
# ['Adventure', 'Comedy', 'Family Film']
# 1
# ['Animation', 'Short Film']
# 2
# ['Musical', 'Action', 'Comedy']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['World cinema', 'Drama']
# 2
# ['Adventure']
# 2
# ['Drama']
# 2
# ['Comedy', 'Crime Fiction', 'Action', 'Romance Film']
# 1
# ['Comedy']
# 1
# ['Comedy', 'Mystery', 'Drama', 'Horror']
# 1
# ['Indie', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Comedy', 'Drama']
# 1
# ['Crime Fiction', 'Indie', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Crime Fiction', 'Comedy', 'Romance Film']
# 1
# ['Romance Film']
# 2
# ['Comedy', 'Short Film']
# 1
# ['Comedy']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Science Fiction', 'Comedy']
# 1
# ['Comedy']
# 1
# ['Short Film', 'Drama']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Thriller', 'World cinema']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Mystery', 'Drama']
# 2
# ['Drama', 'Romance Film']
# 2
# ['Action', 'Drama']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Horror']
# 2
# ['Science Fiction', 'Thriller', 'Horror']
# 2
# ['Action', 'Science Fiction', 'Thriller']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Adventure', 'Comedy', 'Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Horror']
# 2
# ['Action/Adventure', 'Adventure', 'Drama']
# 2
# ['Drama']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Indie', 'Crime Fiction', 'Drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Romantic drama', 'Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Action']
# 2
# ['Drama']
# 2
# ['World cinema', 'Horror']
# 2
# ['World cinema', 'Horror']
# 2
# ['Black-and-white', 'Adventure', 'Action']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Drama']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Animation', 'World cinema', 'Family Film']
# 2
# ['Action', 'Thriller', 'Mystery', 'Drama', 'Action/Adventure']
# 2
# ['Comedy', 'Drama']
# 1
# ['Black-and-white', 'Adventure']
# 2
# ['Science Fiction']
# 2
# ['Musical', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Short Film']
# 2
# ['World cinema', 'Drama']
# 2
# ['Science Fiction']
# 2
# ['Action/Adventure', 'Science Fiction', 'World cinema']
# 2
# ['Science Fiction', 'Drama']
# 2
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Mystery']
# 2
# ['Family Film']
# 2
# ['Musical', 'Comedy', 'Family Film', 'Romance Film']
# 1
# ['Romance Film', 'Drama']
# 2
# ['Comedy']
# 1
# ['Black-and-white', 'Crime Fiction', 'Drama']
# 2
# ['Black-and-white', 'Thriller', 'Drama']
# 2
# ['Animation', 'Adventure', 'Family Film']
# 2
# ['Family Film', 'Comedy', 'Romance Film', 'Science Fiction', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Indie', 'Comedy']
# 1
# ['Indie', 'Drama']
# 2
# ['Crime Fiction', 'Comedy', 'Science Fiction', 'Thriller', 'Drama', 'World cinema']
# 1
# ['Comedy', 'Horror']
# 1
# ['Comedy']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Horror']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Black-and-white']
# 2
# ['Science Fiction']
# 2
# ['Indie', 'Horror']
# 2
# ['Comedy', 'Family Film']
# 1
# ['Romance Film']
# 2
# ['Horror']
# 2
# ['Drama']
# 2
# ['Musical', 'Comedy', 'Horror']
# 1
# ['Drama']
# 2
# ['Black-and-white', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Horror']
# 2
# ['Science Fiction']
# 2
# ['Drama']
# 2
# ['Action', 'Drama']
# 2
# ['Comedy']
# 1
# ['Comedy', 'Horror']
# 1
# ['Indie', 'Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Comedy', 'World cinema']
# 1
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Black-and-white', 'Adventure', 'Drama']
# 2
# ['Animation', 'Adventure', 'Family Film']
# 2
# ['Crime Fiction', 'Science Fiction', 'Thriller', 'Horror']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Black-and-white', 'Action', 'Indie', 'Adventure', 'Drama', 'Action/Adventure']
# 2
# ['Horror']
# 2
# ['Drama']
# 2
# ['Short Film']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['World cinema', 'Drama']
# 2
# ['World cinema', 'Thriller', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Adventure']
# 2
# ['Black-and-white', 'Romantic drama', 'Action', 'Romance Film', 'Drama']
# 2
# ['Action/Adventure']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Action', 'Science Fiction', 'Thriller', 'Horror']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['World cinema', 'Drama']
# 2
# ['Science Fiction', 'Comedy', 'Family Film']
# 1
# ['Thriller', 'Horror']
# 2
# ['Black-and-white', 'Horror', 'Indie', 'Science Fiction', 'Mystery']
# 2
# ['Action']
# 2
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Crime Fiction', 'Drama']
# 2
# ['Romance Film']
# 2
# ['Drama']
# 2
# ['Thriller', 'World cinema']
# 2
# ['Short Film']
# 2
# ['Short Film', 'Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Family Film', 'Comedy', 'Animation', 'Adventure', 'Science Fiction']
# 1
# ['Romance Film', 'Drama']
# 2
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 1
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Musical', 'Family Film', 'Comedy', 'Romance Film', 'Drama']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['World cinema', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Musical', 'Romance Film']
# 2
# ['Action', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Thriller', 'Mystery']
# 2
# ['Black-and-white']
# 2
# ['Indie', 'Drama']
# 2
# ['Drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Thriller', 'Mystery']
# 2
# ['Black-and-white', 'Action', 'Drama']
# 2
# ['Action', 'Comedy', 'Indie', 'Adventure', 'Action/Adventure']
# 1
# ['Animation', 'Adventure', 'Romance Film']
# 2
# ['Action', 'Romance Film', 'Drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Thriller', 'Mystery', 'Drama', 'Horror']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Action', 'Animation', 'Adventure', 'Science Fiction', 'Drama', 'World cinema']
# 2
# ['Romance Film']
# 2
# ['Drama']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Indie', 'Science Fiction', 'Horror']
# 2
# ['Comedy']
# 1
# ['Adventure', 'World cinema', 'Drama']
# 2
# ['Animation']
# 2
# ['Drama']
# 2
# ['Comedy', 'World cinema', 'Horror']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Horror']
# 2
# ['Crime Fiction', 'Action', 'Drama']
# 2
# ['Black-and-white', 'Thriller', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Short Film']
# 2
# ['Action/Adventure', 'Drama']
# 2
# ['Action', 'Romance Film', 'Drama']
# 2
# ['Comedy']
# 1
# ['Drama', 'Horror']
# 2
# ['Crime Fiction', 'Romantic drama', 'Action', 'Comedy', 'Romance Film', 'Indie', 'Thriller', 'Romantic comedy', 'Drama', 'Action/Adventure']
# 1
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Adventure', 'Family Film', 'Drama']
# 2
# ['Short Film']
# 2
# ['Action/Adventure']
# 2
# ['Black-and-white', 'Adventure', 'Action', 'Short Film']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Crime Fiction', 'Romance Film', 'Drama']
# 2
# ['Animation', 'Science Fiction']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Drama']
# 2
# ['Thriller', 'Drama']
# 2
# ['Crime Fiction']
# 2
# ['World cinema', 'Drama']
# 2
# ['Black-and-white', 'Thriller', 'Mystery', 'Horror']
# 2
# ['World cinema', 'Drama']
# 2
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 2
# ['Black-and-white', 'Musical', 'Drama']
# 2
# ['Adventure', 'Family Film']
# 2
# ['Short Film', 'Horror']
# 2
# ['Black-and-white', 'Indie', 'Drama']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Drama', 'Thriller', 'World cinema', 'Romance Film']
# 2
# ['Musical', 'Crime Fiction', 'World cinema', 'Drama']
# 2
# ['Science Fiction', 'Family Film']
# 2
# ['Musical']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Crime Fiction', 'Action', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Black-and-white', 'Adventure']
# 2
# ['Action/Adventure', 'Action', 'World cinema']
# 2
# ['Thriller', 'World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Horror']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Comedy']
# 1
# ['Comedy']
# 1
# ['Crime Fiction', 'Thriller', 'World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Action', 'Comedy', 'World cinema']
# 1
# ['Black-and-white', 'Comedy', 'Indie', 'Short Film']
# 1
# ['Musical', 'Comedy']
# 1
# ['Short Film']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Comedy', 'Drama']
# 1
# ['Black-and-white', 'Indie', 'Short Film']
# 2
# ['Crime Fiction', 'Indie', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Mystery']
# 2
# ['World cinema', 'Drama']
# 2
# ['Black-and-white', 'Crime Fiction', 'Horror', 'Science Fiction', 'Thriller']
# 2
# ['Comedy']
# 1
# ['Musical', 'Indie']
# 2
# ['Black-and-white']
# 2
# ['Comedy', 'Drama']
# 1
# ['Action', 'Comedy', 'Horror']
# 1
# ['Black-and-white', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 2
# ['Action/Adventure', 'Comedy', 'World cinema']
# 1
# ['Short Film']
# 2
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 2
# ['Indie', 'Comedy']
# 1
# ['Black-and-white', 'Action/Adventure', 'Adventure', 'Action']
# 2
# ['Comedy']
# 1
# ['Romance Film']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Drama']
# 2
# ['Indie', 'Horror']
# 2
# ['Short Film']
# 2
# ['Black-and-white']
# 2
# ['Animation', 'Short Film']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['Crime Fiction', 'Comedy', 'Indie', 'Thriller', 'Drama']
# 1
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Drama']
# 2
# ['Crime Fiction', 'Romantic drama', 'Comedy', 'Romance Film', 'Drama']
# 1
# ['Indie', 'Horror']
# 2
# ['Musical', 'Comedy', 'Drama', 'Horror']
# 1
# ['Crime Fiction', 'Science Fiction', 'Drama']
# 2
# ['Musical', 'World cinema']
# 2
# ['Indie', 'Comedy', 'Short Film']
# 1
# ['Black-and-white', 'Action', 'Thriller']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Adventure', 'Action', 'Drama']
# 2
# ['Action', 'Indie', 'Adventure', 'Science Fiction', 'Action/Adventure']
# 2
# ['Musical', 'Comedy']
# 1
# ['Animation', 'Short Film']
# 2
# ['Comedy', 'Romance Film']
# 1
# ['Drama', 'Musical', 'Romance Film', 'Romantic drama']
# 2
# ['Indie', 'Comedy']
# 1
# ['Comedy']
# 1
# ['Black-and-white', 'Horror']
# 2
# ['Black-and-white', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Comedy']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Drama']
# 2
# ['Action/Adventure', 'Action', 'Comedy']
# 1
# ['Indie', 'Drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Action', 'Crime Fiction', 'Science Fiction', 'Thriller']
# 2
# ['Black-and-white', 'Adventure']
# 2
# ['Animation', 'Short Film']
# 2
# ['Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Science Fiction', 'Thriller']
# 2
# ['Action', 'Drama']
# 2
# ['Action/Adventure']
# 2
# ['Crime Fiction']
# 2
# ['Thriller', 'Mystery', 'Drama']
# 2
# ['Action']
# 2
# ['Drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Adventure', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Black-and-white', 'Romance Film', 'Drama']
# 2
# ['Drama', 'Action', 'Romance Film', 'Romantic drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Action', 'World cinema']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Adventure', 'Action']
# 2
# ['Comedy', 'Drama']
# 1
# ['Comedy']
# 1
# ['Action/Adventure', 'Action', 'Thriller', 'World cinema']
# 2
# ['Romance Film']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Action', 'Thriller', 'Drama']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['Thriller', 'Drama']
# 2
# ['Indie', 'Drama']
# 2
# ['Romantic comedy']
# 2
# ['Comedy', 'Indie', 'Thriller', 'Drama', 'World cinema']
# 1
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller']
# 2
# ['Comedy', 'World cinema']
# 1
# ['Horror']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Action']
# 2
# ['Family Film', 'Action', 'Comedy', 'Science Fiction', 'Action/Adventure']
# 1
# ['World cinema', 'Drama']
# 2
# ['Crime Fiction', 'Action', 'Romance Film', 'Thriller', 'Mystery', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Animation', 'Family Film']
# 2
# ['Adventure', 'Science Fiction', 'Horror']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery']
# 2
# ['Comedy', 'Horror']
# 1
# ['Action', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Crime Fiction', 'Horror', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Mystery', 'Drama']
# 2
# ['Comedy', 'Mystery']
# 1
# ['Crime Fiction', 'Action', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Thriller', 'Horror']
# 2
# ['Animation', 'Comedy', 'Indie', 'Short Film']
# 1
# ['Drama']
# 2
# ['Animation', 'Adventure', 'Family Film']
# 2
# ['Action']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Indie', 'Horror']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Adventure', 'Family Film']
# 2
# ['Short Film']
# 2
# ['Short Film']
# 2
# ['Black-and-white', 'Comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Action']
# 2
# ['Musical', 'World cinema', 'Drama']
# 2
# ['Black-and-white']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Crime Fiction', 'Action', 'Thriller', 'Drama']
# 2
# ['Black-and-white']
# 2
# ['Crime Fiction', 'Horror']
# 2
# ['Science Fiction', 'Comedy', 'Horror']
# 1
# ['Romance Film', 'Comedy', 'Romantic comedy', 'Drama']
# 1
# ['Comedy', 'World cinema']
# 1
# ['Science Fiction']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Drama']
# 2
# ['Action', 'Thriller']
# 2
# ['Horror']
# 2
# ['Musical', 'Crime Fiction', 'World cinema', 'Drama']
# 2
# ['Black-and-white', 'Mystery', 'Drama']
# 2
# ['Horror']
# 2
# ['Indie', 'Thriller', 'Drama', 'Horror']
# 2
# ['Adventure', 'Action', 'Romance Film', 'Drama']
# 2
# ['Thriller', 'Family Film']
# 2
# ['Action/Adventure', 'Comedy', 'Crime Fiction', 'Action']
# 1
# ['Drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Action', 'Thriller']
# 2
# ['Romance Film']
# 2
# ['Thriller', 'Drama']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Adventure', 'Comedy', 'Family Film']
# 1
# ['Romance Film', 'World cinema', 'Drama']
# 2
# ['Indie', 'Romance Film', 'Drama']
# 2
# ['Comedy', 'Romantic comedy']
# 1
# ['Adventure', 'World cinema', 'Drama']
# 2
# ['Short Film', 'Drama']
# 2
# ['Action', 'Comedy']
# 1
# ['Short Film']
# 2
# ['Horror']
# 2
# ['Horror']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Science Fiction', 'Thriller']
# 2
# ['Black-and-white', 'Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Short Film']
# 2
# ['Black-and-white', 'Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Short Film']
# 2
# ['Musical', 'World cinema', 'Drama']
# 2
# ['Action', 'Family Film', 'Drama']
# 2
# ['Indie', 'Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Animation', 'Musical', 'Science Fiction', 'Family Film']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Animation', 'Short Film']
# 2
# ['Action']
# 2
# ['Mystery', 'Science Fiction', 'Thriller', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Crime Fiction', 'Action', 'Comedy', 'Thriller', 'Action/Adventure', 'World cinema']
# 1
# ['Comedy']
# 1
# ['Animation', 'Comedy', 'Drama']
# 1
# ['Drama']
# 2
# ['Animation', 'Comedy', 'Short Film']
# 1
# ['World cinema', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Drama', 'Short Film']
# 1
# ['Indie', 'Crime Fiction', 'Action', 'Drama']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Drama']
# 2
# ['Action', 'Thriller']
# 2
# ['Horror']
# 2
# ['Drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Romance Film']
# 2
# ['Black-and-white', 'Action/Adventure', 'Action', 'Drama']
# 2
# ['Indie', 'Action', 'Thriller', 'Horror']
# 2
# ['Action/Adventure']
# 2
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Drama']
# 2
# ['Horror']
# 2
# ['Black-and-white']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Crime Fiction', 'Action', 'Indie', 'Thriller', 'Mystery', 'Action/Adventure']
# 2
# ['Family Film']
# 2
# ['Action/Adventure', 'Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Action', 'Thriller']
# 2
# ['Drama']
# 2
# ['Animation', 'Science Fiction', 'Comedy']
# 1
# ['Family Film', 'Action', 'Comedy', 'Adventure', 'Science Fiction', 'Drama']
# 1
# ['Action', 'Comedy', 'Drama']
# 1
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Adventure', 'Action', 'Family Film']
# 2
# ['Musical', 'Comedy', 'Romantic comedy']
# 1
# ['Black-and-white', 'Indie', 'World cinema', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Musical', 'Horror']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Black-and-white', 'Short Film', 'Family Film', 'Comedy', 'Indie']
# 1
# ['Horror']
# 2
# ['Adventure', 'Comedy', 'Family Film']
# 1
# ['Indie', 'Drama']
# 2
# ['Adventure', 'Family Film', 'Drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Thriller']
# 2
# ['Action', 'Drama']
# 2
# ['Drama']
# 2
# ['Indie', 'Drama']
# 2
# ['Science Fiction', 'Adventure', 'Comedy']
# 1
# ['Animation', 'Comedy', 'Family Film']
# 1
# ['Romantic comedy', 'Drama']
# 2
# ['Drama']
# 2
# ['Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Family Film']
# 2
# ['Thriller', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Romance Film', 'Action', 'Thriller', 'Drama']
# 2
# ['Comedy', 'Romance Film']
# 1
# ['Horror']
# 2
# ['Crime Fiction', 'Comedy', 'Indie', 'Thriller', 'Drama']
# 1
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['Science Fiction', 'Comedy', 'Mystery']
# 1
# ['Indie', 'Comedy']
# 1
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Romance Film']
# 2
# ['Drama', 'World cinema', 'Romance Film']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Adventure', 'Comedy', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Comedy', 'World cinema']
# 1
# ['Action', 'Science Fiction', 'Horror']
# 2
# ['Drama']
# 2
# ['Family Film', 'Animation', 'Adventure', 'Science Fiction', 'World cinema']
# 2
# ['Crime Fiction', 'Action', 'Drama']
# 2
# ['Crime Fiction', 'Action', 'Romance Film', 'Adventure', 'Thriller']
# 2
# ['Black-and-white', 'Action', 'Romance Film', 'Thriller', 'Mystery', 'Action/Adventure']
# 2
# ['Drama']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 2
# ['Adventure', 'Action', 'Science Fiction', 'Thriller']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Musical', 'Action', 'Drama']
# 2
# ['Romance Film']
# 2
# ['Thriller']
# 2
# ['Musical', 'Drama']
# 2
# ['Romantic drama', 'Drama']
# 2
# ['Animation', 'Musical', 'Short Film']
# 2
# ['Black-and-white', 'Adventure', 'Action', 'Science Fiction']
# 2
# ['Mystery', 'Horror']
# 2
# ['Adventure', 'Science Fiction', 'Family Film', 'Drama']
# 2
# ['Short Film']
# 2
# ['Action', 'Drama']
# 2
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Thriller', 'Horror']
# 2
# ['Comedy', 'Horror']
# 1
# ['Indie']
# 2
# ['Animation', 'Musical', 'Comedy']
# 1
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 2
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 1
# ['Drama', 'Crime Fiction', 'Thriller', 'Romantic drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Adventure', 'Drama']
# 2
# ['Musical', 'Indie', 'Drama']
# 2
# ['Indie', 'Drama']
# 2
# ['Thriller', 'Horror']
# 2
# ['Comedy', 'Drama']
# 1
# ['Comedy', 'Short Film']
# 1
# ['Comedy', 'Family Film']
# 1
# ['Drama', 'Action/Adventure', 'Indie', 'Adventure']
# 2
# ['Comedy', 'Drama']
# 1
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Short Film']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Action', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Animation', 'Thriller', 'Comedy', 'Family Film']
# 1
# ['Drama']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Crime Fiction', 'Horror', 'Action', 'Comedy', 'Adventure', 'Indie', 'Thriller', 'Action/Adventure']
# 1
# ['Comedy']
# 1
# ['Thriller', 'Drama']
# 2
# ['Black-and-white', 'Indie', 'World cinema', 'Drama']
# 2
# ['Adventure']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Romantic drama', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Thriller', 'Mystery', 'Drama']
# 2
# ['Short Film', 'Drama']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['Drama']
# 2
# ['Indie', 'Comedy']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Horror']
# 2
# ['Musical']
# 2
# ['Drama']
# 2
# ['Romantic comedy']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Thriller', 'Mystery', 'Drama']
# 2
# ['Comedy', 'Horror']
# 1
# ['Adventure', 'Comedy']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Horror']
# 2
# ['Indie', 'Comedy']
# 1
# ['Indie', 'Comedy']
# 1
# ['Black-and-white', 'Horror', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Musical', 'Drama']
# 2
# ['Indie', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Drama']
# 2
# ['Comedy', 'Romance Film']
# 1
# ['Action']
# 2
# ['Science Fiction', 'World cinema', 'Horror']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Black-and-white', 'World cinema', 'Drama']
# 2
# ['Indie', 'Crime Fiction', 'Comedy']
# 1
# ['Drama', 'Indie', 'Comedy', 'Romance Film']
# 1
# ['Musical', 'Comedy']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Adventure', 'Action']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Crime Fiction', 'World cinema', 'Drama']
# 2
# ['Animation', 'Short Film']
# 2
# ['Drama']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Action/Adventure', 'Action', 'Comedy', 'World cinema']
# 1
# ['Drama']
# 2
# ['Adventure', 'Drama']
# 2
# ['Short Film']
# 2
# ['Black-and-white', 'Adventure', 'Indie', 'Short Film']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Horror']
# 2
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Drama']
# 2
# ['Thriller', 'Mystery']
# 2
# ['Comedy']
# 1
# ['Musical', 'Indie', 'Drama']
# 2
# ['Animation', 'Musical', 'Short Film']
# 2
# ['Short Film']
# 2
# ['Black-and-white', 'Crime Fiction', 'Comedy']
# 1
# ['Mystery', 'Comedy', 'Thriller']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Adventure', 'Action', 'Comedy', 'Romance Film']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Animation', 'Adventure', 'Science Fiction']
# 2
# ['Drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Short Film', 'Drama']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Thriller', 'Drama', 'Horror']
# 2
# ['Animation', 'Musical', 'Comedy', 'Romantic comedy']
# 1
# ['Black-and-white', 'Action', 'Thriller', 'Mystery']
# 2
# ['Romantic drama']
# 2
# ['Black-and-white', 'Musical', 'Family Film', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Thriller', 'Family Film']
# 2
# ['Drama']
# 2
# ['Action', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Short Film']
# 2
# ['Romance Film', 'Comedy', 'Romantic comedy', 'Romantic drama']
# 1
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Action', 'Science Fiction', 'World cinema']
# 2
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Black-and-white']
# 2
# ['Mystery', 'Crime Fiction', 'Comedy', 'Thriller']
# 1
# ['Drama']
# 2
# ['Crime Fiction', 'Action']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Action/Adventure', 'Adventure', 'Action', 'Thriller']
# 2
# ['Science Fiction', 'Thriller']
# 2
# ['Black-and-white', 'Crime Fiction', 'Drama']
# 2
# ['Musical', 'Family Film', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Romantic drama', 'Romance Film', 'Adventure', 'Drama', 'Action/Adventure']
# 2
# ['Drama']
# 2
# ['Drama', 'Indie', 'Romance Film', 'Romantic drama']
# 2
# ['Action', 'Thriller']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 2
# ['Romance Film', 'Action', 'Comedy', 'Drama']
# 1
# ['Science Fiction', 'Indie', 'Comedy']
# 1
# ['Comedy', 'Drama']
# 1
# ['Adventure', 'Science Fiction']
# 2
# ['Thriller', 'Horror']
# 2
# ['Family Film', 'Drama']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Crime Fiction', 'Family Film', 'Action', 'Comedy', 'Adventure', 'Drama']
# 1
# ['Romantic comedy']
# 2
# ['Short Film', 'Action', 'Comedy', 'Indie', 'Adventure', 'Science Fiction']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Crime Fiction', 'Thriller', 'World cinema', 'Drama']
# 2
# ['Science Fiction', 'Horror']
# 2
# ['Action/Adventure', 'Adventure', 'Action']
# 2
# ['Comedy']
# 1
# ['Comedy', 'Family Film']
# 1
# ['Action', 'Family Film']
# 2
# ['Thriller']
# 2
# ['Drama']
# 2
# ['Musical', 'World cinema', 'Family Film', 'Drama']
# 2
# ['Action', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'World cinema', 'Drama']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery']
# 2
# ['Animation', 'Family Film']
# 2
# ['Black-and-white', 'Family Film', 'Drama']
# 2
# ['Horror']
# 2
# ['Science Fiction', 'Adventure', 'Comedy']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Action']
# 2
# ['Drama', 'Romance Film']
# 2
# ['Drama', 'Science Fiction', 'Romance Film']
# 2
# ['Black-and-white', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Action', 'Adventure', 'Science Fiction', 'Thriller', 'Drama']
# 2
# ['Animation']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Horror']
# 2
# ['Drama']
# 2
# ['Thriller']
# 2
# ['Drama']
# 2
# ['Indie', 'Comedy']
# 1
# ['Drama']
# 2
# ['Thriller', 'Drama', 'Horror']
# 2
# ['Adventure', 'Drama']
# 2
# ['Black-and-white', 'Thriller', 'Horror']
# 2
# ['Short Film']
# 2
# ['Action', 'Adventure', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Romantic drama', 'Drama']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Family Film', 'Drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Musical']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Comedy', 'Action']
# 1
# ['Thriller']
# 2
# ['Action']
# 2
# ['Romance Film']
# 2
# ['Horror']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Romantic comedy', 'Comedy', 'Family Film']
# 1
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Horror']
# 2
# ['Adventure']
# 2
# ['Adventure', 'Thriller']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Drama']
# 2
# ['Comedy', 'Family Film']
# 1
# ['Drama']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Family Film', 'Action', 'Comedy', 'Adventure', 'Thriller', 'Action/Adventure']
# 1
# ['Adventure', 'Family Film', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Indie', 'Drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Comedy', 'Indie', 'Thriller', 'Mystery']
# 1
# ['Science Fiction', 'Thriller', 'Horror']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Indie', 'Crime Fiction', 'Action', 'Drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Crime Fiction', 'Mystery', 'Drama']
# 2
# ['Drama']
# 2
# ['Animation', 'Action', 'Science Fiction']
# 2
# ['Action', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Action', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Horror']
# 2
# ['Horror']
# 2
# ['Science Fiction', 'Action/Adventure', 'Adventure', 'Comedy']
# 1
# ['World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Musical', 'Comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Horror']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Action/Adventure', 'Adventure', 'World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Comedy']
# 1
# ['Horror']
# 2
# ['Horror']
# 2
# ['Comedy', 'Crime Fiction', 'Action']
# 1
# ['Black-and-white', 'Drama']
# 2
# ['Comedy', 'Romantic comedy']
# 1
# ['Drama']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 2
# ['Action']
# 2
# ['Action', 'Science Fiction', 'Horror']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Action/Adventure', 'Indie', 'Action', 'Comedy']
# 1
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Drama']
# 2
# ['Romantic drama', 'Drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Comedy']
# 1
# ['Black-and-white', 'World cinema', 'Drama']
# 2
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Animation', 'Short Film']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Black-and-white', 'Musical', 'Comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Comedy', 'Horror']
# 1
# ['Animation', 'Comedy', 'Short Film']
# 1
# ['Crime Fiction', 'Thriller']
# 2
# ['Animation', 'Short Film']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Musical', 'World cinema']
# 2
# ['Musical', 'Short Film', 'Family Film', 'Comedy', 'Animation']
# 1
# ['Crime Fiction', 'Mystery', 'Drama']
# 2
# ['Musical', 'Drama']
# 2
# ['Short Film', 'Drama']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Comedy']
# 1
# ['Musical', 'Comedy']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Horror']
# 2
# ['Animation', 'Short Film']
# 2
# ['Musical']
# 2
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Action/Adventure', 'World cinema']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Comedy']
# 1
# ['Action/Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Action', 'Comedy', 'World cinema']
# 1
# ['Crime Fiction', 'Thriller', 'Drama', 'Horror']
# 2
# ['Black-and-white', 'Romantic comedy', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Science Fiction', 'Comedy', 'Drama']
# 1
# ['Crime Fiction']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Indie', 'Drama']
# 2
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 1
# ['Musical', 'Indie', 'Comedy']
# 1
# ['Mystery', 'Drama']
# 2
# ['Horror']
# 2
# ['Action', 'Indie', 'Science Fiction', 'Thriller', 'Mystery', 'Action/Adventure']
# 2
# ['Comedy']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Science Fiction', 'Horror']
# 2
# ['Thriller', 'Drama']
# 2
# ['Drama']
# 2
# ['Family Film', 'Comedy', 'Adventure', 'Science Fiction', 'Thriller', 'Action/Adventure']
# 1
# ['Comedy']
# 1
# ['Comedy', 'Drama']
# 1
# ['Comedy', 'Horror']
# 1
# ['Comedy']
# 1
# ['Horror']
# 2
# ['Black-and-white', 'Romantic drama', 'Action', 'Romance Film', 'Adventure', 'Action/Adventure']
# 2
# ['Short Film']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Drama']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Thriller', 'Mystery']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Action/Adventure', 'Action', 'Thriller', 'World cinema']
# 2
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Family Film', 'Drama']
# 2
# ['Comedy']
# 1
# ['Musical', 'Comedy', 'Drama', 'Romance Film']
# 1
# ['Action/Adventure', 'Horror']
# 2
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Romance Film', 'Drama']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Action', 'World cinema']
# 2
# ['Comedy', 'Drama']
# 1
# ['Romance Film', 'Drama']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Short Film', 'Drama']
# 2
# ['Thriller', 'Horror']
# 2
# ['Science Fiction', 'Thriller', 'Horror']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Comedy']
# 1
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 2
# ['Short Film']
# 2
# ['Horror']
# 2
# ['Romantic drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Family Film', 'Action', 'Animation', 'Adventure', 'Science Fiction']
# 2
# ['Action', 'Drama']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Drama']
# 2
# ['Animation', 'Short Film']
# 2
# ['Crime Fiction', 'Action', 'Drama']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Drama', 'World cinema']
# 1
# ['Crime Fiction', 'Action', 'Drama']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Romantic comedy']
# 2
# ['Musical', 'Family Film', 'Drama']
# 2
# ['Action']
# 2
# ['Thriller', 'Horror']
# 2
# ['Family Film', 'Action', 'Comedy', 'Animation', 'Adventure']
# 1
# ['Animation', 'Action', 'Science Fiction']
# 2
# ['Animation', 'Musical']
# 2
# ['Black-and-white', 'Indie', 'Horror']
# 2
# ['Drama']
# 2
# ['Comedy', 'World cinema']
# 1
# ['Thriller', 'Mystery', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama', 'Action', 'Romance Film', 'Romantic drama']
# 2
# ['Indie', 'Drama']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Indie', 'World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama', 'Crime Fiction', 'World cinema', 'Romance Film']
# 2
# ['World cinema', 'Horror']
# 2
# ['World cinema', 'Drama']
# 2
# ['Indie', 'Crime Fiction', 'Family Film', 'Drama']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Thriller', 'Drama']
# 2
# ['Comedy']
# 1
# ['World cinema', 'Drama']
# 2
# ['Action', 'Comedy', 'Indie', 'Adventure', 'Drama', 'Action/Adventure', 'World cinema']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Comedy', 'World cinema', 'Romantic comedy', 'Romance Film']
# 1
# ['Action/Adventure', 'Crime Fiction', 'Action', 'Drama']
# 2
# ['Romance Film']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Musical']
# 2
# ['Action/Adventure', 'Adventure', 'Action', 'Drama']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Comedy', 'Family Film']
# 1
# ['Black-and-white', 'Romantic drama', 'Romance Film', 'Indie', 'Drama']
# 2
# ['Science Fiction', 'Mystery', 'Drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Musical']
# 2
# ['Romance Film']
# 2
# ['Black-and-white', 'Musical', 'Comedy', 'Romance Film', 'Romantic comedy']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Drama']
# 1
# ['Drama']
# 2
# ['Action/Adventure', 'World cinema', 'Drama']
# 2
# ['Science Fiction', 'Comedy', 'Short Film']
# 1
# ['Comedy', 'Drama']
# 1
# ['Animation', 'Adventure', 'Science Fiction', 'Family Film']
# 2
# ['Thriller', 'Drama']
# 2
# ['Animation', 'Short Film']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Comedy', 'Romance Film', 'Thriller', 'Mystery', 'Romantic comedy']
# 1
# ['Action/Adventure', 'Action', 'Comedy']
# 1
# ['Horror']
# 2
# ['Thriller', 'Drama']
# 2
# ['Crime Fiction', 'Action', 'Comedy', 'Indie', 'Thriller', 'Action/Adventure']
# 1
# ['Action', 'Adventure', 'Thriller', 'Drama', 'World cinema']
# 2
# ['Action', 'Comedy']
# 1
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Horror']
# 2
# ['Romance Film']
# 2
# ['Horror']
# 2
# ['Crime Fiction', 'Action', 'Thriller', 'Drama', 'Action/Adventure']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Comedy', 'Drama']
# 1
# ['Adventure', 'Family Film', 'Drama']
# 2
# ['Adventure', 'Science Fiction']
# 2
# ['Comedy', 'Horror']
# 1
# ['Science Fiction', 'Horror']
# 2
# ['Adventure', 'Action']
# 2
# ['Comedy']
# 1
# ['Horror']
# 2
# ['Crime Fiction', 'Comedy', 'Indie', 'Thriller', 'Drama']
# 1
# ['Black-and-white', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Comedy', 'Short Film', 'Family Film']
# 1
# ['Drama']
# 2
# ['World cinema', 'Drama', 'Horror']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Black-and-white', 'Short Film']
# 2
# ['Drama']
# 2
# ['Thriller', 'Mystery', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'World cinema']
# 1
# ['World cinema', 'Drama']
# 2
# ['Indie']
# 2
# ['Comedy', 'Romance Film']
# 1
# ['Indie', 'Comedy', 'Family Film']
# 1
# ['Thriller', 'Drama']
# 2
# ['Thriller', 'Horror']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Thriller']
# 2
# ['Indie', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Drama', 'Musical', 'Romance Film']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Animation', 'Short Film']
# 2
# ['Family Film', 'Drama']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Action', 'Drama']
# 2
# ['Short Film']
# 2
# ['Action', 'Animation', 'Science Fiction', 'Thriller', 'Action/Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Comedy']
# 1
# ['Action']
# 2
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Action/Adventure', 'World cinema']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Comedy']
# 1
# ['Crime Fiction', 'Drama']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Action/Adventure', 'Action', 'Science Fiction', 'Thriller']
# 2
# ['Drama']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Crime Fiction', 'Action', 'Thriller', 'Drama', 'Action/Adventure']
# 2
# ['Black-and-white', 'Short Film', 'Family Film', 'Comedy', 'Indie']
# 1
# ['Drama']
# 2
# ['Drama', 'Musical', 'Romance Film', 'Romantic drama']
# 2
# ['Animation', 'Adventure', 'Comedy', 'Family Film']
# 1
# ['Action/Adventure', 'Action', 'World cinema']
# 2
# ['Musical', 'Comedy', 'Drama']
# 1
# ['Horror']
# 2
# ['Drama', 'Comedy', 'Romance Film', 'Horror']
# 1
# ['World cinema']
# 2
# ['Action', 'Romance Film']
# 2
# ['Comedy']
# 1
# ['Action/Adventure', 'World cinema', 'Drama']
# 2
# ['Family Film', 'Drama']
# 2
# ['Drama']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Musical', 'Comedy', 'Family Film']
# 1
# ['Romance Film', 'Drama']
# 2
# ['Science Fiction']
# 2
# ['Action', 'Comedy']
# 1
# ['Indie', 'Drama']
# 2
# ['Indie', 'Crime Fiction']
# 2
# ['Indie', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Musical', 'Short Film']
# 2
# ['Crime Fiction', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Science Fiction', 'Thriller', 'Drama', 'Horror']
# 2
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Romance Film']
# 2
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Drama']
# 2
# ['Musical', 'World cinema', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Animation', 'Action', 'Drama']
# 2
# ['Horror']
# 2
# ['Drama']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Animation', 'Short Film']
# 2
# ['Drama']
# 2
# ['Animation', 'Adventure', 'Action', 'Science Fiction']
# 2
# ['Black-and-white', 'Romance Film']
# 2
# ['Indie', 'Comedy', 'Drama']
# 1
# ['Comedy', 'Family Film']
# 1
# ['Action', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure']
# 2
# ['Indie']
# 2
# ['Mystery', 'Adventure', 'Comedy', 'Family Film']
# 1
# ...
# 2
# ['Crime Fiction', 'Thriller', 'Horror']
# 2
# ['Romance Film', 'Comedy', 'Drama']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Black-and-white']
# 2
# ['Drama']
# 2
# ['Adventure', 'Drama']
# 2
# ['Thriller']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Indie', 'Thriller', 'Drama']
# 2
# ['Action', 'Science Fiction', 'Horror']
# 2
# ['Romance Film']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Indie', 'Comedy', 'World cinema', 'Drama']
# 1
# ['Adventure', 'Action', 'Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Crime Fiction', 'Action', 'Comedy', 'Thriller', 'Action/Adventure']
# 1
# ['Musical']
# 2
# ['Black-and-white']
# 2
# ['Action/Adventure', 'Adventure', 'World cinema', 'Family Film']
# 2
# ['Short Film']
# 2
# ['Science Fiction', 'Horror']
# 2
# ['Horror']
# 2
# ['Animation', 'Short Film']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Romance Film']
# 2
# ['Crime Fiction', 'Action', 'Comedy', 'Thriller', 'Mystery']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Black-and-white', 'Indie', 'Short Film']
# 2
# ['Adventure']
# 2
# ['Animation', 'Comedy', 'Family Film']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Thriller']
# 2
# ['Comedy', 'Family Film']
# 1
# ['Black-and-white', 'Comedy']
# 1
# ['Horror']
# 2
# ['Action', 'Science Fiction']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Black-and-white', 'Thriller']
# 2
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['World cinema', 'Thriller', 'Mystery']
# 2
# ['Romance Film', 'Thriller', 'Drama']
# 2
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Adventure', 'Science Fiction']
# 2
# ['Horror']
# 2
# ['Action']
# 2
# ['Comedy', 'Thriller', 'Drama', 'Horror']
# 1
# ['Animation']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Action/Adventure', 'Musical', 'World cinema', 'Drama']
# 2
# ['Adventure', 'Family Film', 'Drama']
# 2
# ['Horror', 'Action', 'Comedy', 'Science Fiction', 'Action/Adventure', 'World cinema']
# 1
# ['Comedy', 'Drama']
# 1
# ['Indie', 'Crime Fiction', 'World cinema', 'Drama']
# 2
# ['Drama', 'Romance Film']
# 2
# ['Indie', 'Drama']
# 2
# ['Action', 'Comedy', 'Romance Film', 'Romantic comedy', 'Action/Adventure']
# 1
# ['Black-and-white', 'Comedy']
# 1
# ['Black-and-white']
# 2
# ['Romance Film']
# 2
# ['Musical', 'Action', 'Romance Film']
# 2
# ['Animation', 'Adventure', 'Science Fiction', 'Family Film']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Thriller', 'Horror']
# 2
# ['Short Film']
# 2
# ['Adventure']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Comedy']
# 1
# ['Crime Fiction', 'Action', 'Thriller', 'Drama', 'Action/Adventure']
# 2
# ['Drama', 'Romance Film', 'Mystery', 'Romantic drama']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Thriller', 'Drama']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Crime Fiction', 'Comedy', 'Thriller', 'Drama', 'World cinema']
# 1
# ['Crime Fiction', 'Action', 'Drama']
# 2
# ['Musical', 'Drama']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Science Fiction', 'Thriller', 'Horror']
# 2
# ['Musical', 'Comedy']
# 1
# ['Comedy', 'Horror']
# 1
# ['Crime Fiction']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Comedy', 'Short Film']
# 1
# ['Action']
# 2
# ['Action']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Animation', 'Family Film']
# 2
# ['Indie', 'Comedy']
# 1
# ['Drama']
# 2
# ['Thriller']
# 2
# ['Crime Fiction', 'World cinema', 'Drama']
# 2
# ['Romantic drama', 'Romance Film', 'Thriller', 'Drama', 'World cinema']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Short Film']
# 2
# ['Crime Fiction', 'Action', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Black-and-white', 'Comedy', 'Indie', 'Short Film']
# 1
# ['Drama']
# 2
# ['Black-and-white', 'Thriller', 'Drama', 'Horror']
# 2
# ['Comedy']
# 1
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Drama']
# 2
# ['Animation', 'Short Film']
# 2
# ['Romance Film', 'Comedy', 'Romantic comedy', 'Drama']
# 1
# ['Comedy', 'Drama']
# 1
# ['Thriller', 'World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Thriller', 'Horror']
# 2
# ['Musical', 'Romantic drama', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Action']
# 2
# ['Crime Fiction', 'Comedy']
# 1
# ['Action/Adventure', 'Action', 'Thriller', 'Drama']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Drama']
# 2
# ['Adventure']
# 2
# ['Action/Adventure', 'Musical', 'Thriller', 'World cinema']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Drama', 'Romance Film', 'Thriller', 'Romantic drama']
# 2
# ['Action', 'Comedy', 'Romance Film', 'Animation', 'Adventure', 'Science Fiction']
# 1
# ['Musical', 'Family Film']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 2
# ['World cinema', 'Drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Indie', 'Science Fiction']
# 2
# ['Musical', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Action', 'Drama']
# 2
# ['Comedy']
# 1
# ['Black-and-white', 'Indie']
# 2
# ['Indie', 'Short Film']
# 2
# ['Indie', 'Comedy']
# 1
# ['World cinema', 'Drama']
# 2
# ['Thriller']
# 2
# ['Comedy', 'World cinema', 'Horror']
# 1
# ['World cinema', 'Drama']
# 2
# ['Comedy']
# 1
# ['Musical', 'Drama']
# 2
# ['Drama']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 2
# ['Science Fiction', 'Horror']
# 2
# ['Musical', 'Comedy', 'Family Film']
# 1
# ['Action/Adventure']
# 2
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Crime Fiction', 'Thriller']
# 2
# ['Musical', 'Indie', 'Comedy']
# 1
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Romantic drama', 'Romance Film', 'Indie', 'Drama', 'World cinema']
# 2
# ['Black-and-white', 'Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Horror', 'Action', 'Thriller', 'Action/Adventure', 'World cinema']
# 2
# ['Action/Adventure', 'Adventure', 'Action', 'Comedy']
# 1
# ['Action/Adventure', 'Action', 'Comedy', 'Thriller']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Comedy']
# 1
# ['Action/Adventure', 'Drama']
# 2
# ['Adventure', 'Short Film']
# 2
# ['Drama']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Action', 'Comedy', 'Romance Film']
# 1
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Action/Adventure', 'Adventure', 'Horror']
# 2
# ['Short Film']
# 2
# ['Short Film']
# 2
# ['Musical', 'Comedy', 'Drama']
# 1
# ['Musical']
# 2
# ['Science Fiction', 'Comedy']
# 1
# ['Comedy']
# 1
# ['Short Film']
# 2
# ['World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Indie', 'Crime Fiction', 'Comedy', 'Drama']
# 1
# ['Indie', 'Thriller', 'Drama']
# 2
# ['Action/Adventure', 'Adventure', 'Drama']
# 2
# ['Crime Fiction', 'Comedy', 'Thriller', 'Drama']
# 1
# ['Family Film', 'Drama']
# 2
# ['Horror']
# 2
# ['Comedy', 'Romance Film']
# 1
# ['Horror']
# 2
# ['Drama']
# 2
# ['Crime Fiction', 'Short Film', 'Horror', 'Thriller', 'Mystery']
# 2
# ['Animation', 'Short Film']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Mystery', 'Drama']
# 2
# ['Thriller', 'Drama', 'Horror']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Action']
# 2
# ['Drama']
# 2
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Indie', 'Drama']
# 2
# ['Animation']
# 2
# ['Drama']
# 2
# ['Drama']
# 2
# ['Romance Film']
# 2
# ['Romance Film']
# 2
# ['Action', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Crime Fiction', 'Action', 'Indie', 'Thriller', 'Drama']
# 2
# ['Drama']
# 2
# ['Musical', 'Romantic drama', 'Horror', 'Romance Film', 'Drama']
# 2
# ['Horror']
# 2
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Musical', 'World cinema', 'Drama']
# 2
# ['Horror']
# 2
# ['Comedy', 'Drama']
# 1
# ['Black-and-white', 'Comedy', 'Indie', 'Short Film']
# 1
# ['Comedy']
# 1
# ['Musical', 'World cinema', 'Drama']
# 2
# ['Adventure', 'Crime Fiction', 'Drama']
# 2
# ['Comedy', 'Romantic drama']
# 1
# ['Black-and-white', 'Comedy', 'Short Film']
# 1
# ['Comedy']
# 1
# ['Action', 'Comedy', 'Adventure', 'Thriller', 'Drama', 'Action/Adventure']
# 1
# ['Romance Film', 'Drama']
# 2
# ['Science Fiction', 'Thriller']
# 2
# ['Thriller', 'Mystery']
# 2
# ['Thriller', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Black-and-white', 'World cinema', 'Drama']
# 2
# ['Science Fiction']
# 2
# ['Black-and-white', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Crime Fiction', 'Action', 'Comedy', 'Adventure', 'Thriller', 'Action/Adventure']
# 1
# ['Drama']
# 2
# ['Short Film']
# 2
# ['Musical', 'Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Romantic comedy', 'Drama']
# 1
# ['World cinema', 'Drama']
# 2
# ['Mystery', 'Horror']
# 2
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Adventure', 'Science Fiction', 'Drama']
# 2
# ['Animation', 'Family Film']
# 2
# ['Action/Adventure', 'Mystery']
# 2
# ['World cinema', 'Comedy', 'Thriller', 'Drama']
# 1
# ['Thriller', 'World cinema', 'Horror']
# 2
# ['Musical', 'World cinema']
# 2
# ['Comedy', 'Horror']
# 1
# ['Romance Film', 'Romantic drama', 'Drama']
# 2
# ['Comedy']
# 1
# ['Crime Fiction', 'World cinema', 'Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Drama', 'Musical', 'Romance Film']
# 2
# ['Animation', 'Musical', 'Family Film', 'Drama']
# 2
# ['Crime Fiction', 'Drama']
# 2
# ['Family Film', 'Drama']
# 2
# ['Romantic comedy']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Musical', 'Thriller', 'World cinema']
# 2
# ['Science Fiction', 'Adventure', 'Action', 'Comedy']
# 1
# ['Drama']
# 2
# ['Drama']
# 2
# ['Animation', 'Short Film', 'Family Film']
# 2
# ['Action', 'Romance Film', 'Drama']
# 2
# ['Indie', 'Mystery', 'Drama']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Drama']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Drama', 'Romance Film']
# 2
# ['Romance Film']
# 2
# ['Animation', 'Comedy', 'Short Film']
# 1
# ['Horror']
# 2
# ['Drama']
# 2
# ['Horror']
# 2
# ['World cinema', 'Drama']
# 2
# ['Comedy', 'Indie', 'Crime Fiction', 'Action']
# 1
# ['Drama']
# 2
# ['Action']
# 2
# ['Mystery']
# 2
# ['Romantic drama', 'Romance Film', 'Drama', 'Action/Adventure', 'World cinema']
# 2
# ['Drama']
# 2
# ['Short Film']
# 2
# ['Animation', 'Adventure', 'Action', 'Family Film']
# 2
# ['Musical', 'Crime Fiction', 'Romantic drama', 'Action', 'Romance Film', 'Drama', 'World cinema']
# 2
# ['Drama']
# 2
# ['Musical', 'Comedy', 'World cinema']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama', 'Adventure', 'Action', 'Romance Film']
# 2
# ['Musical', 'World cinema']
# 2
# ['Drama']
# 2
# ['Comedy', 'Family Film', 'Drama']
# 1
# ['Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Black-and-white', 'Comedy', 'Indie', 'Short Film']
# 1
# ['Romance Film', 'World cinema', 'Drama']
# 2
# ['Action']
# 2
# ['Science Fiction', 'Musical', 'Comedy']
# 1
# ['Animation', 'Comedy', 'Family Film']
# 1
# ['Comedy', 'Drama']
# 1
# ['Animation', 'Short Film']
# 2
# ['Black-and-white', 'Comedy', 'Drama']
# 1
# ['Thriller', 'World cinema', 'Drama']
# 2
# ['Horror']
# 2
# ['Comedy']
# 1
# ['Musical']
# 2
# ['World cinema', 'Drama']
# 2
# ['Science Fiction', 'Comedy', 'Family Film']
# 1
# ['Action/Adventure']
# 2
# ['Drama', 'Romance Film', 'World cinema', 'Romantic drama']
# 2
# ['Musical', 'Romance Film']
# 2
# ['Drama']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Indie', 'Drama']
# 1
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Drama']
# 2
# ['Thriller', 'World cinema', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Crime Fiction', 'Thriller', 'Horror']
# 2
# ['Action', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'Action/Adventure']
# 1
# ['Animation']
# 2
# ['Black-and-white', 'Comedy', 'Short Film', 'Family Film']
# 1
# ['Drama', 'Romance Film']
# 2
# ['Thriller', 'Mystery', 'Horror']
# 2
# ['Drama']
# 2
# ['Black-and-white']
# 2
# ['Adventure', 'Comedy', 'Drama']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['World cinema', 'Drama', 'Horror']
# 2
# ['Horror']
# 2
# ['Drama']
# 2
# ['Black-and-white', 'Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama']
# 1
# ['Action/Adventure']
# 2
# ['Indie', 'Drama']
# 2
# ['Adventure']
# 2
# ['Comedy', 'Horror']
# 1
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Indie', 'World cinema', 'Drama']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Drama', 'Science Fiction', 'Thriller', 'Romance Film']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Black-and-white', 'Adventure']
# 2
# ['Action/Adventure', 'Comedy', 'World cinema']
# 1
# ['Drama']
# 2
# ['Indie', 'Crime Fiction', 'Thriller', 'Drama']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Drama']
# 2
# ['Adventure', 'Action']
# 2
# ['Crime Fiction', 'Horror', 'Thriller', 'Mystery', 'Drama']
# 2
# ['Animation', 'Comedy', 'Family Film']
# 1
# ['Comedy', 'Drama']
# 1
# ['Black-and-white', 'Indie', 'Action', 'Drama']
# 2
# ['Animation', 'Short Film']
# 2
# ['Indie', 'Comedy']
# 1
# ['Action', 'Comedy', 'Adventure', 'Drama', 'World cinema']
# 1
# ['Action', 'Thriller', 'Drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Science Fiction']
# 2
# ['Indie', 'Comedy']
# 1
# ['Romance Film']
# 2
# ['Musical', 'Crime Fiction', 'Action', 'Comedy', 'Drama', 'World cinema']
# 1
# ['Comedy', 'Drama']
# 1
# ['World cinema', 'Drama']
# 2
# ['Horror']
# 2
# ['Comedy', 'Short Film']
# 1
# ['Drama', 'Family Film', 'Romance Film']
# 2
# ['Indie', 'Comedy']
# 1
# ['Black-and-white', 'Comedy', 'Horror', 'Short Film']
# 1
# ['Science Fiction', 'Horror']
# 2
# ['Indie', 'Short Film', 'Drama']
# 2
# ['Science Fiction', 'World cinema']
# 2
# ['Action/Adventure', 'Crime Fiction', 'Action', 'World cinema']
# 2
# ['Drama']
# 2
# ['Indie', 'Drama']
# 2
# ['Adventure']
# 2
# ['Romance Film']
# 2
# ['Musical', 'Comedy']
# 1
# ['Horror']
# 2
# ['Musical', 'Comedy', 'World cinema', 'Romance Film']
# 1
# ['Comedy']
# 1
# ['Animation', 'World cinema', 'Science Fiction', 'Thriller']
# 2
# ['Action/Adventure', 'Action']
# 2
# ['Action', 'Science Fiction']
# 2
# ['Drama']
# 2
# ['Action']
# 2
# ['Adventure', 'Action']
# 2
# ['Black-and-white', 'Action/Adventure', 'Action']
# 2
# ['Crime Fiction', 'Thriller', 'Action']
# 2
# ['Comedy', 'Drama']
# 1
# ['Short Film']
# 2
# ['Comedy']
# 1
# ['Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Crime Fiction', 'Comedy', 'Action', 'Romance Film']
# 1
# ['Indie', 'Short Film']
# 2
# ['Comedy', 'Horror']
# 1
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Horror']
# 2
# ['Indie', 'Drama']
# 2
# ['Action/Adventure', 'Adventure']
# 2
# ['Indie', 'Comedy']
# 1
# ['Comedy']
# 1
# ['Action', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Crime Fiction', 'Action', 'Thriller', 'Mystery', 'Action/Adventure']
# 2
# ['Drama']
# 2
# ['Thriller']
# 2
# ['Short Film', 'Horror']
# 2
# ['Action/Adventure', 'Action', 'Thriller']
# 2
# ['Comedy', 'World cinema', 'Drama']
# 1
# ['Drama']
# 2
# ['Action', 'Drama']
# 2
# ['Drama', 'Romance Film']
# 2
# ['Crime Fiction', 'Romantic drama', 'Romance Film', 'Thriller', 'Mystery', 'Drama', 'World cinema']
# 2
# ['Action/Adventure', 'Adventure', 'Action', 'Comedy']
# 1
# ['Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Science Fiction', 'Horror']
# 2
# ['Action/Adventure', 'Adventure', 'Science Fiction', 'Drama']
# 2
# ['Animation', 'Comedy', 'Family Film', 'Short Film']
# 1
# ['Horror']
# 2
# ['Horror']
# 2
# ['Black-and-white', 'Crime Fiction', 'Drama']
# 2
# ['Comedy']
# 1
# ['Drama', 'Romance Film', 'Romantic drama']
# 2
# ['Black-and-white', 'Drama', 'Romance Film']
# 2
# ['Crime Fiction', 'Action', 'Mystery', 'Romance Film']
# 2
# ['Romantic drama', 'Comedy', 'Romance Film', 'Romantic comedy', 'Drama', 'World cinema']
# 1
# ['Black-and-white', 'Short Film', 'Drama']
# 2
# ['Black-and-white', 'Drama']
# 2
# ['Drama']
# 2
# ['Thriller', 'Drama']
# 2
# ['Science Fiction', 'Comedy', 'Family Film']
# 1
# ['Drama']
# 2
# ['Mystery', 'Science Fiction', 'Thriller']
# 2
# ['Adventure', 'Crime Fiction', 'Action', 'Mystery']
# 2
# ['Adventure', 'Science Fiction', 'Thriller']
# 2
# ['Romance Film', 'World cinema', 'Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Black-and-white', 'Musical', 'Drama']
# 2
# ['Thriller', 'World cinema', 'Drama']
# 2
# ['Drama']
# 2
# ['Animation', 'Science Fiction']
# 2
# ['Romantic comedy', 'Comedy', 'Family Film', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Short Film']
# 2
# ['Comedy', 'World cinema']
# 1
# ['Indie']
# 2
# ['Drama']
# 2
# ['Romance Film', 'Drama']
# 2
# ['Comedy', 'Drama']
# 1
# ['Action', 'Comedy', 'Thriller', 'Action/Adventure', 'World cinema']
# 1
# ['Action/Adventure', 'Crime Fiction', 'Action', 'Thriller']
# 2
# ['Drama']
# 2
# ['Comedy']
# 1
# ['Action', 'Adventure', 'Science Fiction', 'Thriller', 'Drama', 'Action/Adventure']
# 2
# ['Musical', 'Family Film', 'Drama']
# 2
# ['Short Film']
# 2
# ['Drama']
# 2
# ['Thriller', 'Drama']
# 2
# ['Drama', 'Comedy', 'Romantic comedy', 'Romance Film']
# 1
# ['Drama']
# 2
# ['Action', 'Drama']
# 2
# ['Indie', 'World cinema', 'Drama']
# 2
# ['Action', 'Drama']
# 2
# ['Comedy', 'Indie', 'Short Film']
# 1
# ['Adventure', 'Science Fiction']
# 2
# ['Action/Adventure', 'World cinema', 'Science Fiction', 'Thriller']
# 2
# ['Horror']
# 2
# ['Romantic drama', 'Romance Film', 'World cinema', 'Drama']
# 2
# ['Comedy']
# 1
# ['Drama']
# 2
# ['Comedy']
# 1

# %%
romance_film=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Romance Film", line):
            print("1")
            romance_film.append(1)
        else:
            print("2")
            romance_film.append(0)

# %%
thriller=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Thriller", line):
            print("1")
            thriller.append(1)
        else:
            print("2")
            thriller.append(0)

# %%
action=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Action", line):
            print("1")
            action.append(1)
        else:
            print("2")
            action.append(0)

# %%
world_cinema =[]

from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("World cinema", line):
            print("1")
            world_cinema.append(1)
        else:
            print("2")
            world_cinema.append(0)

# %%
crime_fiction=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Crime Fiction", line):
            print("1")
            crime_fiction.append(1)
        else:
            print("2")
            crime_fiction.append(0)

# %%
horror=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Horror", line):
            print("1")
            horror.append(1)
        else:
            print("2")
            horror.append(0)

# %%
bnw=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Black-and-white", line):
            print("1")
            bnw.append(1)
        else:
            print("2")
            bnw.append(0)

# %%
indie=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Indie", line):
            print("1")
            indie.append(1)
        else:
            print("2")
            indie.append(0)

# %%
ana=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Action/Adventure", line):
            print("1")
            ana.append(1)
        else:
            print("2")
            ana.append(0)

# %%
adventure=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Adventure", line):
            print("1")
            adventure.append(1)
        else:
            print("2")
            adventure.append(0)

# %%
family_film=[]
from re import search
for line in xxx_list:
    #line = line.strip()
    #words = line.split(',')
    #for word in line:
        print(line)
        if search("Family Film", line):
            print("1")
            family_film.append(1)
        else:
            print("2")
            family_film.append(0)

# %%
short_film = []
from re import search
for line in xxx_list:
        print(line)
        if search("Short Film", line):
            print("1")
            short_film.append(1)
        else:
            print("2")
            short_film.append(0)

# %%
animation = []
from re import search
for line in xxx_list:
        print(line)
        if search("Animation", line):
            print("1")
            animation.append(1)
        else:
            print("2")
            animation.append(0)

# %%
romantic_drama=[]

from re import search
for line in xxx_list:
        print(line)
        if search("Romantic drama", line):
            print("1")
            romantic_drama.append(1)
        else:
            print("2")
            romantic_drama.append(0)

# %%
musical=[]

from re import search
for line in xxx_list:
        print(line)
        if search("Musical", line):
            print("1")
            musical.append(1)
        else:
            print("2")
            musical.append(0)

# %%
science_fiction =[]

from re import search
for line in xxx_list:
        print(line)
        if search("Science Fiction", line):
            print("1")
            science_fiction.append(1)
        else:
            print("2")
            science_fiction.append(0)

# %%
mystery=[]
from re import search
for line in xxx_list:
        print(line)
        if search("Mystery", line):
            print("1")
            mystery.append(1)
        else:
            print("2")
            mystery.append(0)

# %%
romantic_comedy=[]
from re import search
for line in xxx_list:
        print(line)
        if search("Romantic Comedy", line):
            print("1")
            romantic_comedy.append(1)
        else:
            print("2")
            romantic_comedy.append(0)

# %%
from pyspark import SparkContext
sc =SparkContext.getOrCreate()

# %%
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)

# %%
from pyspark.sql.functions import monotonically_increasing_id, row_number
b = sqlContext.createDataFrame([(i,) for i in drama], ["drama"])

# %%
c= sqlContext.createDataFrame([(i,) for i in comedy], ["comedy"])

# %%
d= sqlContext.createDataFrame([(i,) for i in romance_film], ["romance_film"])

# %%
e=sqlContext.createDataFrame([(i,) for i in thriller], ["thriller"])

# %%
f= sqlContext.createDataFrame([(i,) for i in action], ["action"])

# %%
g = sqlContext.createDataFrame([(i,) for i in world_cinema], ["world_cinema"])

# %%
h = sqlContext.createDataFrame([(i,) for i in crime_fiction], ["crime_fiction"])

# %%
i_horror = sqlContext.createDataFrame([(i,) for i in horror], ["horror"])

# %%
j = sqlContext.createDataFrame([(i,) for i in bnw], ["bnw"])

# %%
k =  sqlContext.createDataFrame([(i,) for i in indie], ["indie"])

# %%
l = sqlContext.createDataFrame([(i,) for i in ana], ["ana"])

# %%
m = sqlContext.createDataFrame([(i,) for i in adventure], ["adventure"])

# %%
n = sqlContext.createDataFrame([(i,) for i in family_film], ["family_film"])

# %%
o = sqlContext.createDataFrame([(i,) for i in short_film], ["short_film"])

# %%
p = sqlContext.createDataFrame([(i,) for i in romantic_drama], ["romantic_drama"])

# %%
q = sqlContext.createDataFrame([(i,) for i in animation], ["animation"])

# %%
r = sqlContext.createDataFrame([(i,) for i in musical], ["musical"])

# %%
s = sqlContext.createDataFrame([(i,) for i in science_fiction], ["science_fiction"])

# %%
t = sqlContext.createDataFrame([(i,) for i in mystery], ["mystery"])

# %%
u = sqlContext.createDataFrame([(i,) for i in romantic_comedy], ["romantic_comedy"])

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
b = b.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(b, df.row_idx == b.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
c = c.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(c, df.row_idx == c.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
d = d.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(d, df.row_idx == d.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
e = e.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(e, df.row_idx == e.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
f = f.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(f, df.row_idx == f.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
g = g.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(g, df.row_idx == g.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
h = h.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(h, df.row_idx == h.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
i_horror = i_horror.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(i_horror, df.row_idx == i_horror.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
j = j.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(j, df.row_idx == j.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
k = k.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(k, df.row_idx == k.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
l = l.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(l, df.row_idx == l.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
m = m.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(m, df.row_idx == m.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
n = n.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(n, df.row_idx == n.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
o = o.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(o, df.row_idx == o.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
p = p.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(p, df.row_idx == p.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
q = q.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(q, df.row_idx == q.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
r = r.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(r, df.row_idx == r.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
s = s.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(s, df.row_idx == s.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
t = t.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(t, df.row_idx == t.row_idx).\
            drop("row_idx")

# %%
df = df.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))
u = u.withColumn("row_idx", row_number().over(Window.orderBy(monotonically_increasing_id())))

# %%
df = df.join(u, df.row_idx == u.row_idx).\
            drop("row_idx")

# %%
df.show()

# %%
df = df.drop("_c3")

# %%
df.show()

# %%
from pyspark.sql.functions import udf,col,lower,regexp_replace

# %%
from pyspark.ml.feature import Tokenizer, StopWordsRemover

# %%
df = df.select('_c0',(lower(regexp_replace('_c2',"[^a-zA-Z\\s]","")).alias('_c2')),'drama','comedy','romance_film','thriller','action','world_cinema','crime_fiction','horror','bnw','indie','ana','adventure','family_film','short_film','romantic_drama','animation','musical','science_fiction','mystery','romantic_comedy')

# %%
from pyspark.ml.feature import RegexTokenizer

# %%
regextokenizer = RegexTokenizer(inputCol='_c2',outputCol='words_token')

# %%
remover = StopWordsRemover(inputCol = 'words_token',outputCol='words_clean')

# %%
#from pyspark.ml.feature import CountVectorizer

# %%
#cv = CountVectorizer(inputCol="words_clean",outputCol="c_features")

# %%
from pyspark.ml.feature import Word2Vec

# %%
w2v = Word2Vec(vectorSize=300,minCount=0,inputCol="words_clean",outputCol="features")

# %%
df.show()

# %%
from pyspark.ml.classification import LogisticRegression

# %%
lr = LogisticRegression(labelCol="drama",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr])

# %%
from pyspark.ml import Pipeline

# %%
model_1= pipeline.fit(df)

# %%
predictions_drama = model_1.transform(df_test)

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
evaluator=BinaryClassificationEvaluator(rawPredictionCol="rawPrediction", labelCol="prediction")

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_drama)))
# Out:
# The area under ROC for test set is 1.0

# %%
df_test = spark.read.option("inferSchema","true").csv("C:/Users/17169/Desktop/test.csv").limit(10)

# %%
df_clean_test = df.select('_c0',(lower(regexp_replace('_c2',"[^a-zA-Z\\s]","")).alias('_c2')))

# %%
regextokenizer = RegexTokenizer(inputCol='_c2',outputCol='words_token')

# %%
remover = StopWordsRemover(inputCol = 'words_token',outputCol='words_clean')

# %%
#cv = CountVectorizer(inputCol="words_clean",outputCol="c_features")

# %%
w2v = Word2Vec(vectorSize=300,minCount=0,inputCol="words_clean",outputCol="features")

# %%
df_test

# %%
outcome = prediction.select('_c0','prediction').collect()

# %%
lr_2 = LogisticRegression(labelCol="comedy",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_2])

# %%
model_2= pipeline.fit(df)

# %%
predictions_comedy = model_2.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_comedy)))

# %%
lr_3 = LogisticRegression(labelCol="romance_film",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_3])

# %%
model_3= pipeline.fit(df)

# %%
predictions_romantic_film = model_3.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_romantic_film)))

# %%
lr_4 = LogisticRegression(labelCol="thriller",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_4])

# %%
model_4= pipeline.fit(df)

# %%
predictions_thriller = model_4.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_thriller)))

# %%
lr_5 = LogisticRegression(labelCol="action",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_5])

# %%
model_5= pipeline.fit(df)

# %%
predictions_action = model_5.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_action)))

# %%
lr_6 = LogisticRegression(labelCol="world_cinema",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_6])

# %%
model_6= pipeline.fit(df)

# %%
predictions_world_cinema = model_6.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_world_cinema)))

# %%
lr_7 = LogisticRegression(labelCol="crime_fiction",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_7])

# %%
model_7= pipeline.fit(df)

# %%
predictions_crime_fiction = model_7.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_crime_fiction)))

# %%
lr_8 = LogisticRegression(labelCol="horror",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_8])

# %%
model_8= pipeline.fit(df)

# %%
predictions_horror = model_8.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_horror)))

# %%
lr_9 = LogisticRegression(labelCol="bnw",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_9])

# %%
model_9= pipeline.fit(df)

# %%
predictions_bnw = model_9.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_bnw)))

# %%
lr_10 = LogisticRegression(labelCol="indie",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,cv,w2v,lr_10])

# %%
model_10= pipeline.fit(df)

# %%
predictions_indie = model_10.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_indie)))

# %%
lr_11 = LogisticRegression(labelCol="ana",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_11])

# %%
model_11= pipeline.fit(df)

# %%
predictions_ana = model_11.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_ana)))

# %%
lr_12 = LogisticRegression(labelCol="adventure",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_12])

# %%
model_12= pipeline.fit(df)

# %%
predictions_adventure = model_12.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_adventure)))

# %%
lr_13 = LogisticRegression(labelCol="family_film",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_13])

# %%
model_13= pipeline.fit(df)

# %%
predictions_family_film = model_13.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_family_film)))

# %%
lr_14 = LogisticRegression(labelCol="short_film",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_14])

# %%
predictions_short_film = model_14.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_short_film)))

# %%
lr_15 = LogisticRegression(labelCol="romantic_drama",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_15])

# %%
predictions_romantic_drama = model_15.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_romantic_drama)))

# %%
lr_16 = LogisticRegression(labelCol="animation",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_16])

# %%
predictions_animation = model_16.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_animation)))

# %%
lr_17 = LogisticRegression(labelCol="musical",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_17])

# %%
predictions_musical = model_17.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_musical)))

# %%
lr_18 = LogisticRegression(labelCol="science_fiction",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_18])

# %%
predictions_science_fiction = model_18.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_science_fiction)))

# %%
lr_19 = LogisticRegression(labelCol="mystery",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_19])

# %%
predictions_mystery = model_19.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_mystery)))

# %%
lr_20 = LogisticRegression(labelCol="romantic_comedy",featuresCol="features",maxIter=10)

# %%
pipeline = Pipeline(stages=[regextokenizer,remover,w2v,lr_20])

# %%
predictions_romantic_comedy = model_20.transform(df_test)

# %%
print("The area under ROC for test set is {}".format(evaluator.evaluate(predictions_romantic_comedy)))
